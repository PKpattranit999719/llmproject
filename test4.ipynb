# %% [markdown]
# # จำลองให้แสดงแผนที่จากการเลือกสถานที่ต่างๆ แบบ drop down List โดยใช้การจำลองข้อมูล

# %%
import folium
from IPython.display import display
import ipywidgets as widgets
import pandas as pd

# ข้อมูลตัวอย่าง: สถานที่ 10 แห่ง
places = [
    {"name": "สถานที่ 1", "latitude": 14.022788, "longitude": 99.978337},
    {"name": "สถานที่ 2", "latitude": 14.050000, "longitude": 99.980000},
    {"name": "สถานที่ 3", "latitude": 14.070000, "longitude": 99.985000},
    {"name": "สถานที่ 4", "latitude": 14.080000, "longitude": 99.970000},
    {"name": "สถานที่ 5", "latitude": 14.060000, "longitude": 99.965000},
    {"name": "สถานที่ 6", "latitude": 14.040000, "longitude": 99.960000},
    {"name": "สถานที่ 7", "latitude": 14.030000, "longitude": 99.955000},
    {"name": "สถานที่ 8", "latitude": 14.025000, "longitude": 99.950000},
    {"name": "สถานที่ 9", "latitude": 14.035000, "longitude": 99.945000},
    {"name": "สถานที่ 10", "latitude": 14.045000, "longitude": 99.940000},
]

# สร้าง DataFrame สำหรับสถานที่
df = pd.DataFrame(places)

# ฟังก์ชันสร้างแผนที่
def create_map(center_lat, center_lon, zoom_start=15):
    m = folium.Map(location=[center_lat, center_lon], zoom_start=zoom_start)
    folium.Marker([center_lat, center_lon],
                  popup="คุณอยู่ที่นี่",
                  icon=folium.Icon(color="blue", icon="info-sign")).add_to(m)
    return m

# ฟังก์ชันอัปเดตแผนที่เมื่อเลือกสถานที่
def update_map(change):
    selected_place = df[df['name'] == dropdown.value].iloc[0]
    lat, lon = selected_place['latitude'], selected_place['longitude']
    m = create_map(lat, lon)
    display(m)

# สร้าง Dropdown สำหรับเลือกสถานที่
dropdown = widgets.Dropdown(
    options=df['name'].tolist(),
    description='สถานที่:',
    value=df['name'].iloc[0]
)

# ตั้งค่าการอัปเดตเมื่อเปลี่ยนค่า Dropdown
dropdown.observe(update_map, names='value')

# สร้าง Layout สำหรับการแสดงผล
display(widgets.VBox([dropdown]))

# แสดงแผนที่เริ่มต้น
initial_place = df.iloc[0]
initial_map = create_map(initial_place['latitude'], initial_place['longitude'])
display(initial_map)
# Out:
# VBox(children=(Dropdown(description='สถานที่:', options=('สถานที่ 1', 'สถานที่ 2', 'สถานที่ 3', 'สถานที่ 4', '…
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_82a9f5d97d2466670d45322f6d44c4f7 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_82a9f5d97d2466670d45322f6d44c4f7&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_82a9f5d97d2466670d45322f6d44c4f7 = L.map(
#                 &quot;map_82a9f5d97d2466670d45322f6d44c4f7&quot;,
#                 {
#                     center: [14.022788, 99.978337],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 15,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_0454272776dbd006017ab5d52aa8472b = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_0454272776dbd006017ab5d52aa8472b.addTo(map_82a9f5d97d2466670d45322f6d44c4f7);
#
#
#             var marker_7a4e2a4578dc75e0b5277451c21cbf2e = L.marker(
#                 [14.022788, 99.978337],
#                 {
# }
#             ).addTo(map_82a9f5d97d2466670d45322f6d44c4f7);
#
#
#             var icon_c5f5893dbb0fc353dc3162f6597b000b = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;blue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#             marker_7a4e2a4578dc75e0b5277451c21cbf2e.setIcon(icon_c5f5893dbb0fc353dc3162f6597b000b);
#
#
#         var popup_4821d351b10fdaaf3030d059bf2c9dfe = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_09c1b2e6f483776a7829e9af1f30f905 = $(`&lt;div id=&quot;html_09c1b2e6f483776a7829e9af1f30f905&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;คุณอยู่ที่นี่&lt;/div&gt;`)[0];
#                 popup_4821d351b10fdaaf3030d059bf2c9dfe.setContent(html_09c1b2e6f483776a7829e9af1f30f905);
#
#
#
#         marker_7a4e2a4578dc75e0b5277451c21cbf2e.bindPopup(popup_4821d351b10fdaaf3030d059bf2c9dfe)
#         ;
#
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d18d599a9a2c3367d560c6130c6c8136 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d18d599a9a2c3367d560c6130c6c8136&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_d18d599a9a2c3367d560c6130c6c8136 = L.map(
#                 &quot;map_d18d599a9a2c3367d560c6130c6c8136&quot;,
#                 {
#                     center: [14.05, 99.98],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 15,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_b1de7e35b23410a9bd013b604eba6b17 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_b1de7e35b23410a9bd013b604eba6b17.addTo(map_d18d599a9a2c3367d560c6130c6c8136);
#
#
#             var marker_3b13ecfe53ba31f11cb1c356268b7de5 = L.marker(
#                 [14.05, 99.98],
#                 {
# }
#             ).addTo(map_d18d599a9a2c3367d560c6130c6c8136);
#
#
#             var icon_be9d2e2255cfd787f288d725fdd14997 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;blue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#             marker_3b13ecfe53ba31f11cb1c356268b7de5.setIcon(icon_be9d2e2255cfd787f288d725fdd14997);
#
#
#         var popup_9334c261e8d53738a8c41c90ed57a17b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c0f2ff538c924b33fb5cf3e5a3c34abe = $(`&lt;div id=&quot;html_c0f2ff538c924b33fb5cf3e5a3c34abe&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;คุณอยู่ที่นี่&lt;/div&gt;`)[0];
#                 popup_9334c261e8d53738a8c41c90ed57a17b.setContent(html_c0f2ff538c924b33fb5cf3e5a3c34abe);
#
#
#
#         marker_3b13ecfe53ba31f11cb1c356268b7de5.bindPopup(popup_9334c261e8d53738a8c41c90ed57a17b)
#         ;
#
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_e28f0c24b178ce05b1b30281f3d5a72d {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_e28f0c24b178ce05b1b30281f3d5a72d&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_e28f0c24b178ce05b1b30281f3d5a72d = L.map(
#                 &quot;map_e28f0c24b178ce05b1b30281f3d5a72d&quot;,
#                 {
#                     center: [14.045, 99.94],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 15,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_229d12e3dd4635daa4ba545b837a4717 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_229d12e3dd4635daa4ba545b837a4717.addTo(map_e28f0c24b178ce05b1b30281f3d5a72d);
#
#
#             var marker_d469c376a116a3831cc600575f02a4c3 = L.marker(
#                 [14.045, 99.94],
#                 {
# }
#             ).addTo(map_e28f0c24b178ce05b1b30281f3d5a72d);
#
#
#             var icon_9214da37342f62ed50e22d144684d00c = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;blue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#             marker_d469c376a116a3831cc600575f02a4c3.setIcon(icon_9214da37342f62ed50e22d144684d00c);
#
#
#         var popup_8c307364917ed42298d2b8e189ef80a4 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1f42d3a1a91e2d67f38a03553e618856 = $(`&lt;div id=&quot;html_1f42d3a1a91e2d67f38a03553e618856&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;คุณอยู่ที่นี่&lt;/div&gt;`)[0];
#                 popup_8c307364917ed42298d2b8e189ef80a4.setContent(html_1f42d3a1a91e2d67f38a03553e618856);
#
#
#
#         marker_d469c376a116a3831cc600575f02a4c3.bindPopup(popup_8c307364917ed42298d2b8e189ef80a4)
#         ;
#
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_bfdb5ff6784ca6919b76d1812bf5f773 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_bfdb5ff6784ca6919b76d1812bf5f773&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_bfdb5ff6784ca6919b76d1812bf5f773 = L.map(
#                 &quot;map_bfdb5ff6784ca6919b76d1812bf5f773&quot;,
#                 {
#                     center: [14.022788, 99.978337],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 15,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_35dc95dfb909b4e9146300cfbedb8fb0 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_35dc95dfb909b4e9146300cfbedb8fb0.addTo(map_bfdb5ff6784ca6919b76d1812bf5f773);
#
#
#             var marker_0c4898ac1c245d2930fd81c555e6b68b = L.marker(
#                 [14.022788, 99.978337],
#                 {
# }
#             ).addTo(map_bfdb5ff6784ca6919b76d1812bf5f773);
#
#
#             var icon_d90120d032bca1e7e78d55d4c43b9ed6 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;blue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#             marker_0c4898ac1c245d2930fd81c555e6b68b.setIcon(icon_d90120d032bca1e7e78d55d4c43b9ed6);
#
#
#         var popup_b83b1e6dd2143504966bae61d55fdbc6 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b97fe43c39ab9e75d7606ad2c721447a = $(`&lt;div id=&quot;html_b97fe43c39ab9e75d7606ad2c721447a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;คุณอยู่ที่นี่&lt;/div&gt;`)[0];
#                 popup_b83b1e6dd2143504966bae61d55fdbc6.setContent(html_b97fe43c39ab9e75d7606ad2c721447a);
#
#
#
#         marker_0c4898ac1c245d2930fd81c555e6b68b.bindPopup(popup_b83b1e6dd2143504966bae61d55fdbc6)
#         ;
#
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c426f9bed14d13a7d9d3fc6d242d907d {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c426f9bed14d13a7d9d3fc6d242d907d&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_c426f9bed14d13a7d9d3fc6d242d907d = L.map(
#                 &quot;map_c426f9bed14d13a7d9d3fc6d242d907d&quot;,
#                 {
#                     center: [14.025, 99.95],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 15,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_9089aa4d6dd417ba12b18302745352ec = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_9089aa4d6dd417ba12b18302745352ec.addTo(map_c426f9bed14d13a7d9d3fc6d242d907d);
#
#
#             var marker_3a0a90009a48173bea680037a443352b = L.marker(
#                 [14.025, 99.95],
#                 {
# }
#             ).addTo(map_c426f9bed14d13a7d9d3fc6d242d907d);
#
#
#             var icon_15a13a822060d96cbe1900ed5a63ee9a = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;blue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#             marker_3a0a90009a48173bea680037a443352b.setIcon(icon_15a13a822060d96cbe1900ed5a63ee9a);
#
#
#         var popup_033000d4b457f81fbcbf558ba6be28c1 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_fd5d028036161d27eea0040a6010c21c = $(`&lt;div id=&quot;html_fd5d028036161d27eea0040a6010c21c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;คุณอยู่ที่นี่&lt;/div&gt;`)[0];
#                 popup_033000d4b457f81fbcbf558ba6be28c1.setContent(html_fd5d028036161d27eea0040a6010c21c);
#
#
#
#         marker_3a0a90009a48173bea680037a443352b.bindPopup(popup_033000d4b457f81fbcbf558ba6be28c1)
#         ;
#
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# # ลองเอา Keyword-Driven Data Filtering with LLM Integration + Filtering by radius calculation of users นำมาแสดงแผนที่

# %%
url ='http://111.223.37.52/v1'
api_key = 'eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJkYXRhIjp7Im9yZ2FuaXphdGlvbl9pZCI6IjY3MzU2NTczYWM4ZjUzNGEwMGUxNjkzZiIsInRva2VuX25hbWUiOiJTRFAtREVWIiwic3RkRGF0ZSI6IjIwMjQtMTEtMTdUMTc6MDA6MDAuMDAwWiJ9LCJpYXQiOjE3MzE5MTczNzksImV4cCI6MTc4Mjc1MjM5OX0.XLU98w0PT4Gy_PzlLhHVWMawkEH8pWpxsYzt3Ffw6xE'

# %%
# 1
from langchain_experimental.agents import create_pandas_dataframe_agent
from langchain_openai import ChatOpenAI
import pandas as pd

# สร้างโมเดลที่ใช้เชื่อมต่อกับเซิร์ฟเวอร์กลาง
llm = ChatOpenAI(
    model='gpt-4o-mini',
    base_url=url,  # URL ของเซิร์ฟเวอร์กลาง
    api_key=api_key,  # API Key สำหรับการเข้าถึงเซิร์ฟเวอร์
    max_tokens=1000  # จำกัดจำนวนโทเค็นในคำตอบ
)

# โหลดข้อมูล
df = pd.read_csv("splitData.csv")  # โหลดไฟล์ข้อมูล

# %%
# 2
from geopy.distance import geodesic

def calculate_distance(user_location, place_location):
    return geodesic(user_location, place_location).kilometers

# ลบแถวที่มีค่า NaN ในคอลัมน์ LATITUDE_LOCATION และ LONGITUDE_LOCATION
df = df.dropna(subset=['LATITUDE_LOCATION', 'LONGITUDE_LOCATION'])

# %%
# 3
def extract_keywords_from_query(query: str) -> str:
    """
    ใช้โมเดล LLM เพื่อแยกคำสำคัญจากคำถามของผู้ใช้
    """
    # ส่งคำถามไปยังโมเดล LLM
    response = llm.invoke(f"แยกคำสำคัญจากคำถามนี้: '{query}' และแสดงคำสำคัญที่เกี่ยวข้องที่สามารถใช้กรองข้อมูลได้")
    
    # ตรวจสอบผลลัพธ์และคืนค่าคำสำคัญ
    return response.content.strip()

# %%
# 4 คำนวณระยะทางแล้วเก็บไว้ในคอลัมน์ DISTANCE และกรองข้อมูลจากระยะทางที่คำนวณได้
def filter_data(df: pd.DataFrame, thai_name: str = None, region: str = None, subdistrict: str = None,
                district: str = None, province: str = None, category: str = None, subtype: str = None,
                user_location: tuple = None, radius: float = None) -> pd.DataFrame:
    """
    ฟังก์ชันกรองข้อมูลจาก DataFrame ตามค่าที่ระบุในคอลัมน์ต่างๆ และพิกัดระยะทาง
    """
    if df.empty:
        print("DataFrame is empty!")
        return pd.DataFrame()

    print("Initial DataFrame shape:", df.shape)

    # กรองข้อมูลตามคอลัมน์
    if thai_name:
        df = df[df['ATT_NAME_TH'].str.contains(thai_name, na=False, case=False)]
    if region:
        df = df[df['REGION_NAME_TH'].str.contains(region, na=False, case=False)]
    if subdistrict:
        df = df[df['SUBDISTRICT_NAME_TH'].str.contains(subdistrict, na=False, case=False)]
    if district:
        df = df[df['DISTRICT_NAME_TH'].str.contains(district, na=False, case=False)]
    if province:
        df = df[df['PROVINCE_NAME_TH'].str.contains(province, na=False, case=False)]
    if category:
        df = df[df['ATTR_CATAGORY_TH'].str.contains(category, na=False, case=False)]
    if subtype:
        df = df[df['ATTR_SUB_TYPE_TH'].str.contains(subtype, na=False, case=False)]

    # กรองข้อมูลตามระยะทาง (ถ้ากำหนดพิกัดผู้ใช้และรัศมี)
    if user_location and radius:
        df['DISTANCE'] = df.apply(
            lambda row: calculate_distance(user_location, (row['LATITUDE_LOCATION'], row['LONGITUDE_LOCATION'])), axis=1
        )
        df = df[df['DISTANCE'] <= radius]

    print("Filtered DataFrame shape:", df.shape)
    return df

# %%
# 5
from langchain.agents import Tool

# สร้าง Custom Tool
filter_data_tool = Tool(
    name="Filter Data",
    func=filter_data,
    description="กรองข้อมูลจาก DataFrame ตามคอลัมน์ต่างๆ เช่น ATT_NAME_TH, REGION_NAME_TH รวมถึงการกรองระยะทางจากพิกัดผู้ใช้"
)

# %%
# 6
from langchain_experimental.agents.agent_toolkits import create_pandas_dataframe_agent

agent = create_pandas_dataframe_agent(
    llm=llm,
    df=df,
    verbose=True,
    allow_dangerous_code=True,  # ใช้ตัวเลือกนี้อย่างระมัดระวัง
    agent_type="tool-calling",
    tools=[filter_data_tool]
)
# Out:
# c:\llmproject\testenv\Lib\site-packages\langchain_experimental\agents\agent_toolkits\pandas\base.py:283: UserWarning: Received additional kwargs {'tools': [Tool(name='Filter Data', description='กรองข้อมูลจาก DataFrame ตามคอลัมน์ต่างๆ เช่น ATT_NAME_TH, REGION_NAME_TH รวมถึงการกรองระยะทางจากพิกัดผู้ใช้', func=<function filter_data at 0x00000220A43002C0>)]} which are no longer supported.
#   warnings.warn(

# %%
# 7 รับค่ามาจากinput user ที่กรองแล้ว
# ตัวอย่างคำถามของผู้ใช้
user_query = "แหล่งท่องเที่ยวสำหรับกิจกรรมพิเศษนันทนาการและความสนใจพิเศษในจังหวัดประจวบคีรีขันธ์ให้หน่อย"

# ใช้ฟังก์ชันแยกคำสำคัญ
keywords = extract_keywords_from_query(user_query)
print("คำสำคัญที่ได้จากคำถาม:", keywords)

# การกรองข้อมูลตามคำสำคัญจากคำถามผู้ใช้
# แยกคำสำคัญที่เกี่ยวข้องกับการกรองข้อมูลออก
province = None
category = None

# กรองข้อมูลตามคำสำคัญของผู้ใช้
filtered_by_user_request = filter_data(
    df=df, 
    province=province,  # กรองจังหวัดตามคำสำคัญที่ได้
    category=category  # กรองประเภทตามคำสำคัญที่ได้
)

# ระบุพิกัดของผู้ใช้และรัศมี
user_location = (10.9, 99.2)  # พิกัดของผู้ใช้
radius = 50  # รัศมี 50 กิโลเมตร

# กรองข้อมูลตามพิกัดหลังจากกรองคำสั่งผู้ใช้แล้ว
filtered_by_location = filter_data(
    df=filtered_by_user_request,
    user_location=user_location,
    radius=radius
)

# แสดงผลลัพธ์สุดท้าย
print("สถานที่ท่องเที่ยวที่กรองแล้วในรัศมี 50 กิโลเมตร:")
print(filtered_by_location[['ATT_NAME_TH', 'PROVINCE_NAME_TH', 'LATITUDE_LOCATION', 'LONGITUDE_LOCATION']])
# Out:
# คำสำคัญที่ได้จากคำถาม: จากคำถาม "แหล่งท่องเที่ยวสำหรับกิจกรรมพิเศษนันทนาการและความสนใจพิเศษในจังหวัดประจวบคีรีขันธ์ให้หน่อย" สามารถแยกคำสำคัญออกมาได้ดังนี้:
#
# 1. แหล่งท่องเที่ยว
# 2. กิจกรรมพิเศษ
# 3. นันทนาการ
# 4. ความสนใจพิเศษ
# 5. จังหวัดประจวบคีรีขันธ์
#
# คำสำคัญที่เกี่ยวข้องที่สามารถใช้กรองข้อมูลได้ ได้แก่:
#
# - ท่องเที่ยว
# - กิจกรรม
# - นันทนาการ
# - ความสนใจ
# - จังหวัด
# - ประจวบคีรีขันธ์
#
# คำเหล่านี้สามารถใช้ในการค้นหาข้อมูลที่เฉพาะเจาะจงเกี่ยวกับแหล่งท่องเที่ยวและกิจกรรมในจังหวัดประจวบคีรีขันธ์ได้อย่างมีประสิทธิภาพ
# Initial DataFrame shape: (8241, 15)
# Filtered DataFrame shape: (8241, 15)
# Initial DataFrame shape: (8241, 15)
# Filtered DataFrame shape: (89, 16)
# สถานที่ท่องเที่ยวที่กรองแล้วในรัศมี 50 กิโลเมตร:
#                     ATT_NAME_TH PROVINCE_NAME_TH  LATITUDE_LOCATION  \
# 158                 ถ้ำแก้วโครำ            ชุมพร          10.648071
# 170                 น้ำตกไทรคู่  ประจวบคีรีขันธ์          11.248322
# 424                  แก่งหินปิด  ประจวบคีรีขันธ์          11.125246
# 427      อุทยานแห่งชาติอ่าวสยาม  ประจวบคีรีขันธ์          11.210102
# 433            ศาลเจ้าปึงเฒ่ากง  ประจวบคีรีขันธ์          11.239124
# ...                         ...              ...                ...
# 7619                อ่าวทุ่งซาง            ชุมพร          10.771717
# 7721               วัดเทพเจริญ             ชุมพร          10.623385
# 7729  ศูนย์กสิกรรมธรรมชาติเพลิน            ชุมพร          10.562734
# 7991                 วัดประเดิม            ชุมพร          10.482337
# 8067                คลองปากปิด   ประจวบคีรีขันธ์          11.195554
#
#       LONGITUDE_LOCATION
# 158            98.990794
# 170            99.334004
# 424            99.381184
# 427            99.524006
# 433            99.411720
# ...                  ...
# 7619           99.411893
# 7721           99.113429
# 7729           99.273942
# 7991           99.154984
# 8067           99.508776
#
# [89 rows x 4 columns]

# %%
# 8 แสดงแผนที่และข้อมูลชื่อสถานที่ที่กรองได้
import folium
from IPython.display import display
import ipywidgets as widgets
import pandas as pd

# คัดเลือก 10 สถานที่แรกจาก DataFrame ที่กรองแล้ว
top_places = filtered_by_location.head(10)

# แปลงข้อมูลสถานที่ให้เป็นรูปแบบที่ต้องการ
places = top_places[['ATT_NAME_TH', 'LATITUDE_LOCATION', 'LONGITUDE_LOCATION']].rename(
    columns={'ATT_NAME_TH': 'name', 'LATITUDE_LOCATION': 'latitude', 'LONGITUDE_LOCATION': 'longitude'}
).to_dict('records')

# สร้าง DataFrame สำหรับสถานที่
df = pd.DataFrame(places)

# ฟังก์ชันสร้างแผนที่
def create_map(center_lat, center_lon, zoom_start=12):
    m = folium.Map(location=[center_lat, center_lon], zoom_start=zoom_start)
    folium.Marker([center_lat, center_lon],
                  popup="คุณอยู่ที่นี่",
                  icon=folium.Icon(color="blue", icon="info-sign")).add_to(m)
    return m

# ฟังก์ชันอัปเดตแผนที่เมื่อเลือกสถานที่
def update_map(change):
    selected_place = df[df['name'] == dropdown.value].iloc[0]
    lat, lon = selected_place['latitude'], selected_place['longitude']
    m = create_map(lat, lon)
    for _, row in df.iterrows():
        folium.Marker([row['latitude'], row['longitude']],
                      popup=row['name'],
                      icon=folium.Icon(color="green")).add_to(m)
    display(m)

# สร้าง Dropdown สำหรับเลือกสถานที่
dropdown = widgets.Dropdown(
    options=df['name'].tolist(),
    description='สถานที่:',
    value=df['name'].iloc[0]
)

# ตั้งค่าการอัปเดตเมื่อเปลี่ยนค่า Dropdown
dropdown.observe(update_map, names='value')

# สร้าง Layout สำหรับการแสดงผล
display(widgets.VBox([dropdown]))

# แสดงแผนที่เริ่มต้น
initial_place = df.iloc[0]
initial_map = create_map(initial_place['latitude'], initial_place['longitude'])
for _, row in df.iterrows():
    folium.Marker([row['latitude'], row['longitude']],
                  popup=row['name'],
                  icon=folium.Icon(color="green")).add_to(initial_map)
display(initial_map)
# Out:
# VBox(children=(Dropdown(description='สถานที่:', options=('ถ้ำแก้วโครำ', 'น้ำตกไทรคู่', 'แก่งหินปิด', 'อุทยานแห…
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c7958ac4d18b0e2a0c18dba23af235cb {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c7958ac4d18b0e2a0c18dba23af235cb&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_c7958ac4d18b0e2a0c18dba23af235cb = L.map(
#                 &quot;map_c7958ac4d18b0e2a0c18dba23af235cb&quot;,
#                 {
#                     center: [10.648071, 98.9907938],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 12,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_eba8b2e552ea19897acc158521296ef9 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_eba8b2e552ea19897acc158521296ef9.addTo(map_c7958ac4d18b0e2a0c18dba23af235cb);
#
#
#             var marker_5abf54ce0563e247e1f2e03fca073e21 = L.marker(
#                 [10.648071, 98.9907938],
#                 {
# }
#             ).addTo(map_c7958ac4d18b0e2a0c18dba23af235cb);
#
#
#             var icon_6b20e95bda275dac90306e61b9784b06 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;blue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#             marker_5abf54ce0563e247e1f2e03fca073e21.setIcon(icon_6b20e95bda275dac90306e61b9784b06);
#
#
#         var popup_d49e5bb851c06322ac4e3e3cb83a32d7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_92cb141da69b7ebb5ddb131901a3d373 = $(`&lt;div id=&quot;html_92cb141da69b7ebb5ddb131901a3d373&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;คุณอยู่ที่นี่&lt;/div&gt;`)[0];
#                 popup_d49e5bb851c06322ac4e3e3cb83a32d7.setContent(html_92cb141da69b7ebb5ddb131901a3d373);
#
#
#
#         marker_5abf54ce0563e247e1f2e03fca073e21.bindPopup(popup_d49e5bb851c06322ac4e3e3cb83a32d7)
#         ;
#
#
#
#
#             var marker_02472e3163196561c9bbed44de3f75a1 = L.marker(
#                 [10.648071, 98.9907938],
#                 {
# }
#             ).addTo(map_c7958ac4d18b0e2a0c18dba23af235cb);
#
#
#             var icon_d297f76be7cb642456872967f27d55b4 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;green&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#             marker_02472e3163196561c9bbed44de3f75a1.setIcon(icon_d297f76be7cb642456872967f27d55b4);
#
#
#         var popup_13fa32ab5118e8cb3585c166454fefd1 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f076004e5018e559caa2bbe074b62567 = $(`&lt;div id=&quot;html_f076004e5018e559caa2bbe074b62567&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;ถ้ำแก้วโครำ&lt;/div&gt;`)[0];
#                 popup_13fa32ab5118e8cb3585c166454fefd1.setContent(html_f076004e5018e559caa2bbe074b62567);
#
#
#
#         marker_02472e3163196561c9bbed44de3f75a1.bindPopup(popup_13fa32ab5118e8cb3585c166454fefd1)
#         ;
#
#
#
#
#             var marker_bb186d1827aa35dc6d6c8ecd7ca725fe = L.marker(
#                 [11.248322, 99.334004],
#                 {
# }
#             ).addTo(map_c7958ac4d18b0e2a0c18dba23af235cb);
#
#
#             var icon_4a1abef214ccb6a5fff1917823a08c0e = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;green&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#             marker_bb186d1827aa35dc6d6c8ecd7ca725fe.setIcon(icon_4a1abef214ccb6a5fff1917823a08c0e);
#
#
#         var popup_530b44e852676f55061141f93f6c6038 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e0d2ab999ac0f93099930f647fd7125f = $(`&lt;div id=&quot;html_e0d2ab999ac0f93099930f647fd7125f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;น้ำตกไทรคู่&lt;/div&gt;`)[0];
#                 popup_530b44e852676f55061141f93f6c6038.setContent(html_e0d2ab999ac0f93099930f647fd7125f);
#
#
#
#         marker_bb186d1827aa35dc6d6c8ecd7ca725fe.bindPopup(popup_530b44e852676f55061141f93f6c6038)
#         ;
#
#
#
#
#             var marker_d99cc014648398b05afd5ba8c214d49e = L.marker(
#                 [11.1252464, 99.3811844],
#                 {
# }
#             ).addTo(map_c7958ac4d18b0e2a0c18dba23af235cb);
#
#
#             var icon_28ec4ad772e820a083989b8f8aa583f9 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;green&quot;
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_55a179cba49759cb23a40ed1e9647b13 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_55a179cba49759cb23a40ed1e9647b13&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_55a179cba49759cb23a40ed1e9647b13 = L.map(
#                 &quot;map_55a179cba49759cb23a40ed1e9647b13&quot;,
#                 {
#                     center: [11.248322, 99.334004],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 12,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_c18128335910282be50d9b5e337c7800 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_c18128335910282be50d9b5e337c7800.addTo(map_55a179cba49759cb23a40ed1e9647b13);
#
#
#             var marker_7e1d25ed66b0adbb3136ce8e2afb005e = L.marker(
#                 [11.248322, 99.334004],
#                 {
# }
#             ).addTo(map_55a179cba49759cb23a40ed1e9647b13);
#
#
#             var icon_04b29b54cfd7b6f31421178e4ea555f8 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;blue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#             marker_7e1d25ed66b0adbb3136ce8e2afb005e.setIcon(icon_04b29b54cfd7b6f31421178e4ea555f8);
#
#
#         var popup_5a0ebf4c14b5a2ff58ba1acaf6c4d780 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_02e1b7b352c0c5925928c5b17b2087c0 = $(`&lt;div id=&quot;html_02e1b7b352c0c5925928c5b17b2087c0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;คุณอยู่ที่นี่&lt;/div&gt;`)[0];
#                 popup_5a0ebf4c14b5a2ff58ba1acaf6c4d780.setContent(html_02e1b7b352c0c5925928c5b17b2087c0);
#
#
#
#         marker_7e1d25ed66b0adbb3136ce8e2afb005e.bindPopup(popup_5a0ebf4c14b5a2ff58ba1acaf6c4d780)
#         ;
#
#
#
#
#             var marker_709e6fc6e0bb132aee647b1780ab8b5b = L.marker(
#                 [10.648071, 98.9907938],
#                 {
# }
#             ).addTo(map_55a179cba49759cb23a40ed1e9647b13);
#
#
#             var icon_1c8ae8cb9efb692e217eb9c260761c97 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;green&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#             marker_709e6fc6e0bb132aee647b1780ab8b5b.setIcon(icon_1c8ae8cb9efb692e217eb9c260761c97);
#
#
#         var popup_355dea28021e52a767e8399ba03899a0 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d4a7ccc65c152cf9d099ec3376471f77 = $(`&lt;div id=&quot;html_d4a7ccc65c152cf9d099ec3376471f77&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;ถ้ำแก้วโครำ&lt;/div&gt;`)[0];
#                 popup_355dea28021e52a767e8399ba03899a0.setContent(html_d4a7ccc65c152cf9d099ec3376471f77);
#
#
#
#         marker_709e6fc6e0bb132aee647b1780ab8b5b.bindPopup(popup_355dea28021e52a767e8399ba03899a0)
#         ;
#
#
#
#
#             var marker_5500b21c4557ed55584b2d02cae059e4 = L.marker(
#                 [11.248322, 99.334004],
#                 {
# }
#             ).addTo(map_55a179cba49759cb23a40ed1e9647b13);
#
#
#             var icon_34a6898c5d28698b2d4fa247b0ca09d4 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;green&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#             marker_5500b21c4557ed55584b2d02cae059e4.setIcon(icon_34a6898c5d28698b2d4fa247b0ca09d4);
#
#
#         var popup_290e29956bd3e25bced3bafba8056ce8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_68945e0685fe3dba6ed46a964d7757ce = $(`&lt;div id=&quot;html_68945e0685fe3dba6ed46a964d7757ce&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;น้ำตกไทรคู่&lt;/div&gt;`)[0];
#                 popup_290e29956bd3e25bced3bafba8056ce8.setContent(html_68945e0685fe3dba6ed46a964d7757ce);
#
#
#
#         marker_5500b21c4557ed55584b2d02cae059e4.bindPopup(popup_290e29956bd3e25bced3bafba8056ce8)
#         ;
#
#
#
#
#             var marker_42255d4fafc3b49d161d539f3b3c6bef = L.marker(
#                 [11.1252464, 99.3811844],
#                 {
# }
#             ).addTo(map_55a179cba49759cb23a40ed1e9647b13);
#
#
#             var icon_d377f282d12c6dee14e60b04e907ee50 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;green&quot;,
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c1f0b6d583d0eeba494a7593ceaeaf3b {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c1f0b6d583d0eeba494a7593ceaeaf3b&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_c1f0b6d583d0eeba494a7593ceaeaf3b = L.map(
#                 &quot;map_c1f0b6d583d0eeba494a7593ceaeaf3b&quot;,
#                 {
#                     center: [11.1252464, 99.3811844],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 12,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_f87678429e446124875a863645a239a3 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_f87678429e446124875a863645a239a3.addTo(map_c1f0b6d583d0eeba494a7593ceaeaf3b);
#
#
#             var marker_91be26eb99790bc6295feb0121229b95 = L.marker(
#                 [11.1252464, 99.3811844],
#                 {
# }
#             ).addTo(map_c1f0b6d583d0eeba494a7593ceaeaf3b);
#
#
#             var icon_df1097150efa8e73d54869039a48223d = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;blue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#             marker_91be26eb99790bc6295feb0121229b95.setIcon(icon_df1097150efa8e73d54869039a48223d);
#
#
#         var popup_a8265c881012b34a763940d430256fa3 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_07b4b3aaca5990752ccf97acb7c3de86 = $(`&lt;div id=&quot;html_07b4b3aaca5990752ccf97acb7c3de86&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;คุณอยู่ที่นี่&lt;/div&gt;`)[0];
#                 popup_a8265c881012b34a763940d430256fa3.setContent(html_07b4b3aaca5990752ccf97acb7c3de86);
#
#
#
#         marker_91be26eb99790bc6295feb0121229b95.bindPopup(popup_a8265c881012b34a763940d430256fa3)
#         ;
#
#
#
#
#             var marker_a74a1ec85b66ec95f2b041e4d8e9a6f0 = L.marker(
#                 [10.648071, 98.9907938],
#                 {
# }
#             ).addTo(map_c1f0b6d583d0eeba494a7593ceaeaf3b);
#
#
#             var icon_d2af64bf661c3da607cc98d065ada272 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;green&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#             marker_a74a1ec85b66ec95f2b041e4d8e9a6f0.setIcon(icon_d2af64bf661c3da607cc98d065ada272);
#
#
#         var popup_a6a943e5a338ebfa263a85494ebf77f2 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_14f0a77728bc5581ef8a89dd71fb3c00 = $(`&lt;div id=&quot;html_14f0a77728bc5581ef8a89dd71fb3c00&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;ถ้ำแก้วโครำ&lt;/div&gt;`)[0];
#                 popup_a6a943e5a338ebfa263a85494ebf77f2.setContent(html_14f0a77728bc5581ef8a89dd71fb3c00);
#
#
#
#         marker_a74a1ec85b66ec95f2b041e4d8e9a6f0.bindPopup(popup_a6a943e5a338ebfa263a85494ebf77f2)
#         ;
#
#
#
#
#             var marker_d35304b19e2a1294828b189db6103229 = L.marker(
#                 [11.248322, 99.334004],
#                 {
# }
#             ).addTo(map_c1f0b6d583d0eeba494a7593ceaeaf3b);
#
#
#             var icon_a07e4468e12ad6f340fc20c4fc579284 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;green&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#             marker_d35304b19e2a1294828b189db6103229.setIcon(icon_a07e4468e12ad6f340fc20c4fc579284);
#
#
#         var popup_1d90cb8ec7602d9e424b6a635490628f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_be3280f92771cd77c4e2896a5ec9383a = $(`&lt;div id=&quot;html_be3280f92771cd77c4e2896a5ec9383a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;น้ำตกไทรคู่&lt;/div&gt;`)[0];
#                 popup_1d90cb8ec7602d9e424b6a635490628f.setContent(html_be3280f92771cd77c4e2896a5ec9383a);
#
#
#
#         marker_d35304b19e2a1294828b189db6103229.bindPopup(popup_1d90cb8ec7602d9e424b6a635490628f)
#         ;
#
#
#
#
#             var marker_bfe14c3e624b3038670d99bfb7784baa = L.marker(
#                 [11.1252464, 99.3811844],
#                 {
# }
#             ).addTo(map_c1f0b6d583d0eeba494a7593ceaeaf3b);
#
#
#             var icon_975bce515732ae8003902cd53e4cbb14 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;green&quo
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_5defbb663b7a44e9676dec651fcac64e {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_5defbb663b7a44e9676dec651fcac64e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_5defbb663b7a44e9676dec651fcac64e = L.map(
#                 &quot;map_5defbb663b7a44e9676dec651fcac64e&quot;,
#                 {
#                     center: [11.2101018, 99.5240058],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 12,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_00104bfddf30fa3ac903857def3ec1cf = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_00104bfddf30fa3ac903857def3ec1cf.addTo(map_5defbb663b7a44e9676dec651fcac64e);
#
#
#             var marker_3471708a78f66efd3de85bfdbc29eecf = L.marker(
#                 [11.2101018, 99.5240058],
#                 {
# }
#             ).addTo(map_5defbb663b7a44e9676dec651fcac64e);
#
#
#             var icon_f71227ce3606cf997aa7ccc7f0ed1777 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;blue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#             marker_3471708a78f66efd3de85bfdbc29eecf.setIcon(icon_f71227ce3606cf997aa7ccc7f0ed1777);
#
#
#         var popup_132106f9030d9ec5e608c026ba246a0d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_369eeeded5d7b103672caef8a85e0d2e = $(`&lt;div id=&quot;html_369eeeded5d7b103672caef8a85e0d2e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;คุณอยู่ที่นี่&lt;/div&gt;`)[0];
#                 popup_132106f9030d9ec5e608c026ba246a0d.setContent(html_369eeeded5d7b103672caef8a85e0d2e);
#
#
#
#         marker_3471708a78f66efd3de85bfdbc29eecf.bindPopup(popup_132106f9030d9ec5e608c026ba246a0d)
#         ;
#
#
#
#
#             var marker_8f6b7172f47de2fd6c36d915894d1fb1 = L.marker(
#                 [10.648071, 98.9907938],
#                 {
# }
#             ).addTo(map_5defbb663b7a44e9676dec651fcac64e);
#
#
#             var icon_56b00e422fd88e2bf75dffcccf8c03cc = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;green&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#             marker_8f6b7172f47de2fd6c36d915894d1fb1.setIcon(icon_56b00e422fd88e2bf75dffcccf8c03cc);
#
#
#         var popup_9ce7acd579b41d736915cb287e60e0b6 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_04333490af335074e1badf99503f91f4 = $(`&lt;div id=&quot;html_04333490af335074e1badf99503f91f4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;ถ้ำแก้วโครำ&lt;/div&gt;`)[0];
#                 popup_9ce7acd579b41d736915cb287e60e0b6.setContent(html_04333490af335074e1badf99503f91f4);
#
#
#
#         marker_8f6b7172f47de2fd6c36d915894d1fb1.bindPopup(popup_9ce7acd579b41d736915cb287e60e0b6)
#         ;
#
#
#
#
#             var marker_572a5a5ecac50d58376f3fc5fb483786 = L.marker(
#                 [11.248322, 99.334004],
#                 {
# }
#             ).addTo(map_5defbb663b7a44e9676dec651fcac64e);
#
#
#             var icon_e84644bb5cade667e2aa2cd6a8484a51 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;green&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#             marker_572a5a5ecac50d58376f3fc5fb483786.setIcon(icon_e84644bb5cade667e2aa2cd6a8484a51);
#
#
#         var popup_4d1e9bca124d257e5ea0aa9c9718e741 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_aad3f28d5c50525b437a745c20557a90 = $(`&lt;div id=&quot;html_aad3f28d5c50525b437a745c20557a90&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;น้ำตกไทรคู่&lt;/div&gt;`)[0];
#                 popup_4d1e9bca124d257e5ea0aa9c9718e741.setContent(html_aad3f28d5c50525b437a745c20557a90);
#
#
#
#         marker_572a5a5ecac50d58376f3fc5fb483786.bindPopup(popup_4d1e9bca124d257e5ea0aa9c9718e741)
#         ;
#
#
#
#
#             var marker_4d2f0bd40a78e18336151196f2cd33d7 = L.marker(
#                 [11.1252464, 99.3811844],
#                 {
# }
#             ).addTo(map_5defbb663b7a44e9676dec651fcac64e);
#
#
#             var icon_5f83a921bf4deff1a3b169fc4fda658b = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;green&quo

# %% [markdown]
# # เพิ่มหมุดของUSER

# %%
# ฟังก์ชันสร้างแผนที่พร้อมแสดงหมุดของผู้ใช้
def create_map(center_lat, center_lon, zoom_start=12, user_lat=None, user_lon=None):
    m = folium.Map(location=[center_lat, center_lon], zoom_start=zoom_start)
    
    # หากมีข้อมูลตำแหน่งของผู้ใช้ ให้แสดงหมุดของผู้ใช้
    if user_lat and user_lon:
        folium.Marker([user_lat, user_lon],
                      popup="คุณอยู่ที่นี่",
                      icon=folium.Icon(color="blue", icon="info-sign")).add_to(m)  # หมุดสีน้ำเงิน
    
    return m

# ฟังก์ชันอัปเดตแผนที่เมื่อเลือกสถานที่
def update_map(change):
    selected_place = df[df['name'] == dropdown.value].iloc[0]
    lat, lon = selected_place['latitude'], selected_place['longitude']
    
    # ใช้ตำแหน่งผู้ใช้จาก user_location ที่ได้รับจากโค้ดก่อนหน้า
    user_lat, user_lon = 10.9, 99.2  # พิกัดของผู้ใช้
    
    m = create_map(lat, lon, user_lat=user_lat, user_lon=user_lon)
    
    # แสดงหมุดของสถานที่ที่เลือก
    for _, row in df.iterrows():
        folium.Marker([row['latitude'], row['longitude']],
                      popup=row['name'],
                      icon=folium.Icon(color="green")).add_to(m)
    display(m)

# สร้าง Dropdown สำหรับเลือกสถานที่
dropdown = widgets.Dropdown(
    options=df['name'].tolist(),
    description='สถานที่:',
    value=df['name'].iloc[0]
)

# ตั้งค่าการอัปเดตเมื่อเปลี่ยนค่า Dropdown
dropdown.observe(update_map, names='value')

# สร้าง Layout สำหรับการแสดงผล
display(widgets.VBox([dropdown]))

# แสดงแผนที่เริ่มต้น
initial_place = df.iloc[0]
# ใช้ตำแหน่งผู้ใช้จาก user_location ที่ได้รับจากโค้ดก่อนหน้า
user_lat, user_lon = 10.9, 99.2  # พิกัดของผู้ใช้

initial_map = create_map(initial_place['latitude'], initial_place['longitude'], user_lat=user_lat, user_lon=user_lon)
# แสดงหมุดของสถานที่
for _, row in df.iterrows():
    folium.Marker([row['latitude'], row['longitude']],
                  popup=row['name'],
                  icon=folium.Icon(color="green")).add_to(initial_map)
display(initial_map)
# Out:
# VBox(children=(Dropdown(description='สถานที่:', options=('ถ้ำแก้วโครำ', 'น้ำตกไทรคู่', 'แก่งหินปิด', 'อุทยานแห…
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_640fa530b084f80cf49d2064c3e9f012 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_640fa530b084f80cf49d2064c3e9f012&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_640fa530b084f80cf49d2064c3e9f012 = L.map(
#                 &quot;map_640fa530b084f80cf49d2064c3e9f012&quot;,
#                 {
#                     center: [10.648071, 98.9907938],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 12,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_8a6bb4cb8b5dd8186fa5fe152bfa4096 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_8a6bb4cb8b5dd8186fa5fe152bfa4096.addTo(map_640fa530b084f80cf49d2064c3e9f012);
#
#
#             var marker_874be7e9ea17a2a9eaad50f4e8436fde = L.marker(
#                 [10.9, 99.2],
#                 {
# }
#             ).addTo(map_640fa530b084f80cf49d2064c3e9f012);
#
#
#             var icon_268ed6c1f3fb5264af2553bbc7bbc476 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;blue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#             marker_874be7e9ea17a2a9eaad50f4e8436fde.setIcon(icon_268ed6c1f3fb5264af2553bbc7bbc476);
#
#
#         var popup_ed9f4764dddf5c7ab81fb829e6d720cb = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d89ec2eeccba4c8e89dbf3ad2cd56527 = $(`&lt;div id=&quot;html_d89ec2eeccba4c8e89dbf3ad2cd56527&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;คุณอยู่ที่นี่&lt;/div&gt;`)[0];
#                 popup_ed9f4764dddf5c7ab81fb829e6d720cb.setContent(html_d89ec2eeccba4c8e89dbf3ad2cd56527);
#
#
#
#         marker_874be7e9ea17a2a9eaad50f4e8436fde.bindPopup(popup_ed9f4764dddf5c7ab81fb829e6d720cb)
#         ;
#
#
#
#
#             var marker_bfa900ec3b95f954e4525320911226fe = L.marker(
#                 [10.648071, 98.9907938],
#                 {
# }
#             ).addTo(map_640fa530b084f80cf49d2064c3e9f012);
#
#
#             var icon_bec5c7b7e1031e843cf92e11324592d3 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;green&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#             marker_bfa900ec3b95f954e4525320911226fe.setIcon(icon_bec5c7b7e1031e843cf92e11324592d3);
#
#
#         var popup_1e185db3bc19b95ddda6b4297183386e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9fdd496704ee43c66d29542bed5861f8 = $(`&lt;div id=&quot;html_9fdd496704ee43c66d29542bed5861f8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;ถ้ำแก้วโครำ&lt;/div&gt;`)[0];
#                 popup_1e185db3bc19b95ddda6b4297183386e.setContent(html_9fdd496704ee43c66d29542bed5861f8);
#
#
#
#         marker_bfa900ec3b95f954e4525320911226fe.bindPopup(popup_1e185db3bc19b95ddda6b4297183386e)
#         ;
#
#
#
#
#             var marker_7484d5dc60bcadfb414bb80fa61758bc = L.marker(
#                 [11.248322, 99.334004],
#                 {
# }
#             ).addTo(map_640fa530b084f80cf49d2064c3e9f012);
#
#
#             var icon_8a6d93cbfe7d49c80727d8c12a94bd4b = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;green&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#             marker_7484d5dc60bcadfb414bb80fa61758bc.setIcon(icon_8a6d93cbfe7d49c80727d8c12a94bd4b);
#
#
#         var popup_61c32a58e3f38b74bbc4a2e013f8bca4 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b01583cdda8de5aa9448512319c536f8 = $(`&lt;div id=&quot;html_b01583cdda8de5aa9448512319c536f8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;น้ำตกไทรคู่&lt;/div&gt;`)[0];
#                 popup_61c32a58e3f38b74bbc4a2e013f8bca4.setContent(html_b01583cdda8de5aa9448512319c536f8);
#
#
#
#         marker_7484d5dc60bcadfb414bb80fa61758bc.bindPopup(popup_61c32a58e3f38b74bbc4a2e013f8bca4)
#         ;
#
#
#
#
#             var marker_4b67b5634ece29e2904571d3a8361433 = L.marker(
#                 [11.1252464, 99.3811844],
#                 {
# }
#             ).addTo(map_640fa530b084f80cf49d2064c3e9f012);
#
#
#             var icon_f3376ccaab5c2ecf6555ad63c1ed6d93 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;green&quot;,
#   &quot;i
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_57926fc4f0c4f20820b0e8a09e3c6090 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_57926fc4f0c4f20820b0e8a09e3c6090&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_57926fc4f0c4f20820b0e8a09e3c6090 = L.map(
#                 &quot;map_57926fc4f0c4f20820b0e8a09e3c6090&quot;,
#                 {
#                     center: [10.477803, 99.207895],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 12,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_4cff45b39b5459129c14fa98ce1d3a05 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_4cff45b39b5459129c14fa98ce1d3a05.addTo(map_57926fc4f0c4f20820b0e8a09e3c6090);
#
#
#             var marker_bd0923d159d34341cd81eaad5e7056c7 = L.marker(
#                 [10.9, 99.2],
#                 {
# }
#             ).addTo(map_57926fc4f0c4f20820b0e8a09e3c6090);
#
#
#             var icon_518997fb1bdb377d154bd6aab43bb148 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;blue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#             marker_bd0923d159d34341cd81eaad5e7056c7.setIcon(icon_518997fb1bdb377d154bd6aab43bb148);
#
#
#         var popup_1a755d8d440da4af975d878b438e609b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7813a3990937e11711d9a5a3570daea4 = $(`&lt;div id=&quot;html_7813a3990937e11711d9a5a3570daea4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;คุณอยู่ที่นี่&lt;/div&gt;`)[0];
#                 popup_1a755d8d440da4af975d878b438e609b.setContent(html_7813a3990937e11711d9a5a3570daea4);
#
#
#
#         marker_bd0923d159d34341cd81eaad5e7056c7.bindPopup(popup_1a755d8d440da4af975d878b438e609b)
#         ;
#
#
#
#
#             var marker_8815becce2b2a8ffb8d35214b03b22c2 = L.marker(
#                 [10.648071, 98.9907938],
#                 {
# }
#             ).addTo(map_57926fc4f0c4f20820b0e8a09e3c6090);
#
#
#             var icon_794ca7fffe436bfb64bd7e5cd5985fb7 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;green&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#             marker_8815becce2b2a8ffb8d35214b03b22c2.setIcon(icon_794ca7fffe436bfb64bd7e5cd5985fb7);
#
#
#         var popup_04956030414510936eaf4b77cbefc8fa = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ac1d9399d0f1ad9fe7df81660b1ba29b = $(`&lt;div id=&quot;html_ac1d9399d0f1ad9fe7df81660b1ba29b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;ถ้ำแก้วโครำ&lt;/div&gt;`)[0];
#                 popup_04956030414510936eaf4b77cbefc8fa.setContent(html_ac1d9399d0f1ad9fe7df81660b1ba29b);
#
#
#
#         marker_8815becce2b2a8ffb8d35214b03b22c2.bindPopup(popup_04956030414510936eaf4b77cbefc8fa)
#         ;
#
#
#
#
#             var marker_fdeb1f101766e9d10ad65af530b5770a = L.marker(
#                 [11.248322, 99.334004],
#                 {
# }
#             ).addTo(map_57926fc4f0c4f20820b0e8a09e3c6090);
#
#
#             var icon_1873842f0342b2cb61e6796e8e7efe70 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;green&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#             marker_fdeb1f101766e9d10ad65af530b5770a.setIcon(icon_1873842f0342b2cb61e6796e8e7efe70);
#
#
#         var popup_9c83c893b6cc820f63b77cbb9294158c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_bd63f79ee2c440c8e08b061e9fcc24cd = $(`&lt;div id=&quot;html_bd63f79ee2c440c8e08b061e9fcc24cd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;น้ำตกไทรคู่&lt;/div&gt;`)[0];
#                 popup_9c83c893b6cc820f63b77cbb9294158c.setContent(html_bd63f79ee2c440c8e08b061e9fcc24cd);
#
#
#
#         marker_fdeb1f101766e9d10ad65af530b5770a.bindPopup(popup_9c83c893b6cc820f63b77cbb9294158c)
#         ;
#
#
#
#
#             var marker_6cc98d2092cd379b0e54d058801075e5 = L.marker(
#                 [11.1252464, 99.3811844],
#                 {
# }
#             ).addTo(map_57926fc4f0c4f20820b0e8a09e3c6090);
#
#
#             var icon_c4b35b4bdc4928faa6e832a054486398 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;green&quot;,
#   &quot;ic
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_f8bd91b9dcbf6b866bb760c7eaaa99ea {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_f8bd91b9dcbf6b866bb760c7eaaa99ea&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_f8bd91b9dcbf6b866bb760c7eaaa99ea = L.map(
#                 &quot;map_f8bd91b9dcbf6b866bb760c7eaaa99ea&quot;,
#                 {
#                     center: [10.7458708, 99.3959464],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 12,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_64d19eab5c9527a585f20c3be19168c2 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_64d19eab5c9527a585f20c3be19168c2.addTo(map_f8bd91b9dcbf6b866bb760c7eaaa99ea);
#
#
#             var marker_0427e59f401eb24461d7514625ba1474 = L.marker(
#                 [10.9, 99.2],
#                 {
# }
#             ).addTo(map_f8bd91b9dcbf6b866bb760c7eaaa99ea);
#
#
#             var icon_607a95f818c26570e597ae5609ee3d5d = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;blue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#             marker_0427e59f401eb24461d7514625ba1474.setIcon(icon_607a95f818c26570e597ae5609ee3d5d);
#
#
#         var popup_5fa2f8d5176ed939531516b6fbe9772f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a34cdb490d4f7c34cbc5d6cd5d7f4fb0 = $(`&lt;div id=&quot;html_a34cdb490d4f7c34cbc5d6cd5d7f4fb0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;คุณอยู่ที่นี่&lt;/div&gt;`)[0];
#                 popup_5fa2f8d5176ed939531516b6fbe9772f.setContent(html_a34cdb490d4f7c34cbc5d6cd5d7f4fb0);
#
#
#
#         marker_0427e59f401eb24461d7514625ba1474.bindPopup(popup_5fa2f8d5176ed939531516b6fbe9772f)
#         ;
#
#
#
#
#             var marker_bd70b6f541ade682904af2c3ac6da095 = L.marker(
#                 [10.648071, 98.9907938],
#                 {
# }
#             ).addTo(map_f8bd91b9dcbf6b866bb760c7eaaa99ea);
#
#
#             var icon_b04d9673630c540e8acb679f1d61b5c4 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;green&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#             marker_bd70b6f541ade682904af2c3ac6da095.setIcon(icon_b04d9673630c540e8acb679f1d61b5c4);
#
#
#         var popup_775865feb8e72e7c6c67287eff7f74ce = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ece14f707d96902b97cf9fcca8347b0d = $(`&lt;div id=&quot;html_ece14f707d96902b97cf9fcca8347b0d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;ถ้ำแก้วโครำ&lt;/div&gt;`)[0];
#                 popup_775865feb8e72e7c6c67287eff7f74ce.setContent(html_ece14f707d96902b97cf9fcca8347b0d);
#
#
#
#         marker_bd70b6f541ade682904af2c3ac6da095.bindPopup(popup_775865feb8e72e7c6c67287eff7f74ce)
#         ;
#
#
#
#
#             var marker_2385edf4f04506ba8f57546b813e953c = L.marker(
#                 [11.248322, 99.334004],
#                 {
# }
#             ).addTo(map_f8bd91b9dcbf6b866bb760c7eaaa99ea);
#
#
#             var icon_87d42980bd2d417944756505e5baf593 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;green&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#             marker_2385edf4f04506ba8f57546b813e953c.setIcon(icon_87d42980bd2d417944756505e5baf593);
#
#
#         var popup_8028356a7c584225e3402f43f2ed33d1 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_08aab654e68b61f3550276dbe6d2fb7e = $(`&lt;div id=&quot;html_08aab654e68b61f3550276dbe6d2fb7e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;น้ำตกไทรคู่&lt;/div&gt;`)[0];
#                 popup_8028356a7c584225e3402f43f2ed33d1.setContent(html_08aab654e68b61f3550276dbe6d2fb7e);
#
#
#
#         marker_2385edf4f04506ba8f57546b813e953c.bindPopup(popup_8028356a7c584225e3402f43f2ed33d1)
#         ;
#
#
#
#
#             var marker_800d3ffff144dfd7e8900c916c7a9786 = L.marker(
#                 [11.1252464, 99.3811844],
#                 {
# }
#             ).addTo(map_f8bd91b9dcbf6b866bb760c7eaaa99ea);
#
#
#             var icon_3b397720dc992579b65db70a7f4f198c = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;green&quot;,
#   &quot;

# %% [markdown]
# # ลองเอาLlamaIndex มาใช้

# %%
! pip install llama_index
# Out:
# Requirement already satisfied: llama_index in .\testenv\lib\site-packages (0.12.5)
# Requirement already satisfied: llama-index-agent-openai<0.5.0,>=0.4.0 in .\testenv\lib\site-packages (from llama_index) (0.4.0)
# Requirement already satisfied: llama-index-cli<0.5.0,>=0.4.0 in .\testenv\lib\site-packages (from llama_index) (0.4.0)
# Requirement already satisfied: llama-index-core<0.13.0,>=0.12.5 in .\testenv\lib\site-packages (from llama_index) (0.12.5)
# Requirement already satisfied: llama-index-embeddings-openai<0.4.0,>=0.3.0 in .\testenv\lib\site-packages (from llama_index) (0.3.1)
# Requirement already satisfied: llama-index-indices-managed-llama-cloud>=0.4.0 in .\testenv\lib\site-packages (from llama_index) (0.6.3)
# Requirement already satisfied: llama-index-legacy<0.10.0,>=0.9.48 in .\testenv\lib\site-packages (from llama_index) (0.9.48.post4)
# Requirement already satisfied: llama-index-llms-openai<0.4.0,>=0.3.0 in .\testenv\lib\site-packages (from llama_index) (0.3.10)
# Requirement already satisfied: llama-index-multi-modal-llms-openai<0.5.0,>=0.4.0 in .\testenv\lib\site-packages (from llama_index) (0.4.0)
# Requirement already satisfied: llama-index-program-openai<0.4.0,>=0.3.0 in .\testenv\lib\site-packages (from llama_index) (0.3.1)
# Requirement already satisfied: llama-index-question-gen-openai<0.4.0,>=0.3.0 in .\testenv\lib\site-packages (from llama_index) (0.3.0)
# Requirement already satisfied: llama-index-readers-file<0.5.0,>=0.4.0 in .\testenv\lib\site-packages (from llama_index) (0.4.1)
# Requirement already satisfied: llama-index-readers-llama-parse>=0.4.0 in .\testenv\lib\site-packages (from llama_index) (0.4.0)
# Requirement already satisfied: nltk>3.8.1 in .\testenv\lib\site-packages (from llama_index) (3.9.1)
# Requirement already satisfied: openai>=1.14.0 in .\testenv\lib\site-packages (from llama-index-agent-openai<0.5.0,>=0.4.0->llama_index) (1.57.4)
# Requirement already satisfied: PyYAML>=6.0.1 in .\testenv\lib\site-packages (from llama-index-core<0.13.0,>=0.12.5->llama_index) (6.0.2)
# Requirement already satisfied: SQLAlchemy>=1.4.49 in .\testenv\lib\site-packages (from SQLAlchemy[asyncio]>=1.4.49->llama-index-core<0.13.0,>=0.12.5->llama_index) (2.0.36)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.6 in .\testenv\lib\site-packages (from llama-index-core<0.13.0,>=0.12.5->llama_index) (3.11.10)
# Requirement already satisfied: dataclasses-json in .\testenv\lib\site-packages (from llama-index-core<0.13.0,>=0.12.5->llama_index) (0.6.7)
# Requirement already satisfied: deprecated>=1.2.9.3 in .\testenv\lib\site-packages (from llama-index-core<0.13.0,>=0.12.5->llama_index) (1.2.15)
# Requirement already satisfied: dirtyjson<2.0.0,>=1.0.8 in .\testenv\lib\site-packages (from llama-index-core<0.13.0,>=0.12.5->llama_index) (1.0.8)
# Requirement already satisfied: filetype<2.0.0,>=1.2.0 in .\testenv\lib\site-packages (from llama-index-core<0.13.0,>=0.12.5->llama_index) (1.2.0)
# Requirement already satisfied: fsspec>=2023.5.0 in .\testenv\lib\site-packages (from llama-index-core<0.13.0,>=0.12.5->llama_index) (2024.10.0)
# Requirement already satisfied: httpx in .\testenv\lib\site-packages (from llama-index-core<0.13.0,>=0.12.5->llama_index) (0.27.2)
# Requirement already satisfied: nest-asyncio<2.0.0,>=1.5.8 in .\testenv\lib\site-packages (from llama-index-core<0.13.0,>=0.12.5->llama_index) (1.6.0)
# Requirement already satisfied: networkx>=3.0 in .\testenv\lib\site-packages (from llama-index-core<0.13.0,>=0.12.5->llama_index) (3.4.2)
# Requirement already satisfied: numpy in .\testenv\lib\site-packages (from llama-index-core<0.13.0,>=0.12.5->llama_index) (1.26.4)
# Requirement already satisfied: pillow>=9.0.0 in .\testenv\lib\site-packages (from llama-index-core<0.13.0,>=0.12.5->llama_index) (11.0.0)
# Requirement already satisfied: pydantic>=2.8.0 in .\testenv\lib\site-packages (from llama-index-core<0.13.0,>=0.12.5->llama_index) (2.10.3)
# Requirement already satisfied: requests>=2.31.0 in .\testenv\lib\site-packages (from llama-index-core<0.13.0,>=0.12.5->llama_index) (2.32.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.2.0 in .\testenv\lib\site-packages (from llama-index-core<0.13.0,>=0.12.5->llama_index) (8.5.0)
# Requirement already satisfied: tiktoken>=0.3.3 in .\testenv\lib\site-packages (from llama-index-core<0.13.0,>=0.12.5->llama_index) (0.8.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.66.1 in .\testenv\lib\site-packages (from llama-index-core<0.13.0,>=0.12.5->llama_index) (4.67.1)
# Requirement already satisfied: typing-extensions>=4.5.0 in .\testenv\lib\site-packages (from llama-index-core<0.13.0,>=0.12.5->llama_index) (4.12.2)
# Requirement already satisfied: typing-inspect>=0.8.0 in .\testenv\lib\site-packages (from llama-index-core<0.13.0,>=0.12.5->llama_index) (0.9.0)
# Requirement already satisfied: wrapt in .\testenv\lib\site-packages (from llama-index-core<0.13.0,>=0.12.5->llama_index) (1.17.0)
# Requirement already satisfied: llama-cloud>=0.1.5 in .\testenv\lib\site-packages (from llama-index-indices-managed-llama-cloud>=0.4.0->llama_index) (0.1.6)
# Requirement already satisfied: pandas in .\testenv\lib\site-packages (from llama-index-legacy<0.10.0,>=0.9.48->llama_index) (2.2.3)
# Requirement already satisfied: beautifulsoup4<5.0.0,>=4.12.3 in .\testenv\lib\site-packages (from llama-index-readers-file<0.5.0,>=0.4.0->llama_index) (4.12.3)
# Requirement already satisfied: pypdf<6.0.0,>=5.1.0 in .\testenv\lib\site-packages (from llama-index-readers-file<0.5.0,>=0.4.0->llama_index) (5.1.0)
# Requirement already satisfied: striprtf<0.0.27,>=0.0.26 in .\testenv\lib\site-packages (from llama-index-readers-file<0.5.0,>=0.4.0->llama_index) (0.0.26)
# Requirement already satisfied: llama-parse>=0.5.0 in .\testenv\lib\site-packages (from llama-index-readers-llama-parse>=0.4.0->llama_index) (0.5.17)
# Requirement already satisfied: click in .\testenv\lib\site-packages (from nltk>3.8.1->llama_index) (8.1.7)
# Requirement already satisfied: joblib in .\testenv\lib\site-packages (from nltk>3.8.1->llama_index) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in .\testenv\lib\site-packages (from nltk>3.8.1->llama_index) (2024.11.6)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in .\testenv\lib\site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.13.0,>=0.12.5->llama_index) (2.4.4)
# Requirement already satisfied: aiosignal>=1.1.2 in .\testenv\lib\site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.13.0,>=0.12.5->llama_index) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in .\testenv\lib\site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.13.0,>=0.12.5->llama_index) (24.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in .\testenv\lib\site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.13.0,>=0.12.5->llama_index) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in .\testenv\lib\site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.13.0,>=0.12.5->llama_index) (6.1.0)
# Requirement already satisfied: propcache>=0.2.0 in .\testenv\lib\site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.13.0,>=0.12.5->llama_index) (0.2.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in .\testenv\lib\site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.13.0,>=0.12.5->llama_index) (1.18.3)
# Requirement already satisfied: soupsieve>1.2 in .\testenv\lib\site-packages (from beautifulsoup4<5.0.0,>=4.12.3->llama-index-readers-file<0.5.0,>=0.4.0->llama_index) (2.6)
# Requirement already satisfied: anyio in .\testenv\lib\site-packages (from httpx->llama-index-core<0.13.0,>=0.12.5->llama_index) (4.7.0)
# Requirement already satisfied: certifi in .\testenv\lib\site-packages (from httpx->llama-index-core<0.13.0,>=0.12.5->llama_index) (2024.12.14)
# Requirement already satisfied: httpcore==1.* in .\testenv\lib\site-packages (from httpx->llama-index-core<0.13.0,>=0.12.5->llama_index) (1.0.7)
# Requirement already satisfied: idna in .\testenv\lib\site-packages (from httpx->llama-index-core<0.13.0,>=0.12.5->llama_index) (3.10)
# Requirement already satisfied: sniffio in .\testenv\lib\site-packages (from httpx->llama-index-core<0.13.0,>=0.12.5->llama_index) (1.3.1)
# Requirement already satisfied: h11<0.15,>=0.13 in .\testenv\lib\site-packages (from httpcore==1.*->httpx->llama-index-core<0.13.0,>=0.12.5->llama_index) (0.14.0)
# Requirement already satisfied: colorama in .\testenv\lib\site-packages (from click->nltk>3.8.1->llama_index) (0.4.6)
# Requirement already satisfied: distro<2,>=1.7.0 in .\testenv\lib\site-packages (from openai>=1.14.0->llama-index-agent-openai<0.5.0,>=0.4.0->llama_index) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.4.0 in .\testenv\lib\site-packages (from openai>=1.14.0->llama-index-agent-openai<0.5.0,>=0.4.0->llama_index) (0.8.2)
# Requirement already satisfied: annotated-types>=0.6.0 in .\testenv\lib\site-packages (from pydantic>=2.8.0->llama-index-core<0.13.0,>=0.12.5->llama_index) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.1 in .\testenv\lib\site-packages (from pydantic>=2.8.0->llama-index-core<0.13.0,>=0.12.5->llama_index) (2.27.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in .\testenv\lib\site-packages (from requests>=2.31.0->llama-index-core<0.13.0,>=0.12.5->llama_index) (3.4.0)
# Requirement already satisfied: urllib3<3,>=1.21.1 in .\testenv\lib\site-packages (from requests>=2.31.0->llama-index-core<0.13.0,>=0.12.5->llama_index) (2.2.3)
# Requirement already satisfied: greenlet!=0.4.17 in .\testenv\lib\site-packages (from SQLAlchemy>=1.4.49->SQLAlchemy[asyncio]>=1.4.49->llama-index-core<0.13.0,>=0.12.5->llama_index) (3.1.1)
# Requirement already satisfied: mypy-extensions>=0.3.0 in .\testenv\lib\site-packages (from typing-inspect>=0.8.0->llama-index-core<0.13.0,>=0.12.5->llama_index) (1.0.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in .\testenv\lib\site-packages (from dataclasses-json->llama-index-core<0.13.0,>=0.12.5->llama_index) (3.23.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in .\testenv\lib\site-packages (from pandas->llama-index-legacy<0.10.0,>=0.9.48->llama_index) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in .\testenv\lib\site-packages (from pandas->llama-index-legacy<0.10.0,>=0.9.48->llama_index) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in .\testenv\lib\site-packages (from pandas->llama-index-legacy<0.10.0,>=0.9.48->llama_index) (2024.2)
# Requirement already satisfied: packaging>=17.0 in .\testenv\lib\site-packages (from marshmallow<4.0.0,>=3.18.0->dataclasses-json->llama-index-core<0.13.0,>=0.12.5->llama_index) (24.2)
# Requirement already satisfied: six>=1.5 in .\testenv\lib\site-packages (from python-dateutil>=2.8.2->pandas->llama-index-legacy<0.10.0,>=0.9.48->llama_index) (1.17.0)
# [notice] A new release of pip is available: 24.2 -> 24.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from llama_index import GPTSimpleVectorIndex, Document
import pandas as pd
from langchain_openai import ChatOpenAI
from geopy.distance import geodesic
from langchain.agents import Tool
from langchain_experimental.agents.agent_toolkits import create_pandas_dataframe_agent

# 1 Data Loading
# สร้างโมเดลที่ใช้เชื่อมต่อกับเซิร์ฟเวอร์กลาง
llm = ChatOpenAI(
    model='gpt-4o-mini',
    base_url=url,  # URL ของเซิร์ฟเวอร์กลาง
    api_key=api_key,  # API Key สำหรับการเข้าถึงเซิร์ฟเวอร์
    max_tokens=1000  # จำกัดจำนวนโทเค็นในคำตอบ
)

# โหลดข้อมูล
df = pd.read_csv("splitData.csv")  # โหลดไฟล์ข้อมูล

# 2 สร้างดัชนี LlamaIndex จากข้อมูล DataFrame
documents = []
for _, row in df.iterrows():
    # สร้าง Document จากข้อมูลในแต่ละแถว
    text = f"ชื่อสถานที่: {row['ATT_NAME_TH']}, จังหวัด: {row['PROVINCE_NAME_TH']}, ประเภท: {row['ATTR_CATAGORY_TH']}, ตำแหน่ง: ({row['LATITUDE_LOCATION']}, {row['LONGITUDE_LOCATION']})"
    documents.append(Document(text=text))

# สร้างดัชนีจากเอกสาร
index = GPTSimpleVectorIndex.from_documents(documents)

# 3 Distance Calculation: คำนวณระยะทางระหว่างตำแหน่งผู้ใช้กับสถานที่ใน DataFrame
def calculate_distance(user_location, place_location):
    return geodesic(user_location, place_location).kilometers

# 4 Keyword Extraction: ใช้ LLM เพื่อแยกคำสำคัญจากคำถามของผู้ใช้
def extract_keywords_from_query(query: str) -> str:
    """
    ใช้โมเดล LLM เพื่อแยกคำสำคัญจากคำถามของผู้ใช้
    """
    # ส่งคำถามไปยังโมเดล LLM
    response = llm.invoke(f"แยกคำสำคัญจากคำถามนี้: '{query}' และแสดงคำสำคัญที่เกี่ยวข้องที่สามารถใช้กรองข้อมูลได้")
    
    # ตรวจสอบผลลัพธ์และคืนค่าคำสำคัญ
    return response.content.strip()

# 5 Tool Creation: ให้ LLM สามารถเรียกใช้ฟังก์ชัน filter_data ได้ (Function Calling)
# สร้าง Custom Tool สำหรับค้นหาจาก LlamaIndex
def search_using_llamaindex(query: str):
    # ใช้ LlamaIndex ในการค้นหาคำสำคัญจากคำถาม
    return index.query(query)

filter_data_tool = Tool(
    name="Search Data",
    func=search_using_llamaindex,
    description="ค้นหาข้อมูลจาก DataFrame โดยใช้ LlamaIndex"
)

# 6 Agent Creation: ใช้ create_pandas_dataframe_agent รวม LLM กับ DataFrame และ Tool
agent = create_pandas_dataframe_agent(
    llm=llm,
    df=df,
    verbose=True,
    allow_dangerous_code=True,  # ใช้ตัวเลือกนี้อย่างระมัดระวัง
    agent_type="tool-calling",
    tools=[filter_data_tool]
)

# 7 User Query Processing: รับคำถามของผู้ใช้ & แยกคำสำคัญ & เพื่อกรองข้อมูลตามคำสำคัญ และ ระยะทาง
user_query = "ช่วยหาแหล่งท่องเที่ยวทางธรรมชาติในจังหวัดนครปฐมให้หน่อย"

# ใช้ฟังก์ชันแยกคำสำคัญ
keywords = extract_keywords_from_query(user_query)
print("คำสำคัญที่ได้จากคำถาม:", keywords)

# ค้นหาข้อมูลจาก LlamaIndex
result = search_using_llamaindex(user_query)
print("ผลการค้นหาจาก LlamaIndex:", result)

# ถ้าต้องการกรองข้อมูลตามระยะทางด้วย
user_location = (14.022788, 99.978337)  # พิกัดของผู้ใช้
radius = 50  # รัศมี 50 กิโลเมตร

# กรองข้อมูลตามระยะทาง
filtered_by_location = df[df.apply(
    lambda row: calculate_distance(user_location, (row['LATITUDE_LOCATION'], row['LONGITUDE_LOCATION'])) <= radius,
    axis=1
)]

# แสดงผลลัพธ์
print("สถานที่ท่องเที่ยวที่กรองแล้วในรัศมี 50 กิโลเมตร:")
print(filtered_by_location[['ATT_NAME_TH', 'PROVINCE_NAME_TH', 'LATITUDE_LOCATION', 'LONGITUDE_LOCATION']])
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 from llama_index import GPTSimpleVectorIndex, Document
#       2 import pandas as pd
#       3 from langchain_openai import ChatOpenAI
#
# ImportError: cannot import name 'GPTSimpleVectorIndex' from 'llama_index' (unknown location)

# %%
! pip install llama_index
# Out:
# Requirement already satisfied: llama_index in .\testenv\lib\site-packages (0.12.5)
# Requirement already satisfied: llama-index-agent-openai<0.5.0,>=0.4.0 in .\testenv\lib\site-packages (from llama_index) (0.4.0)
# Requirement already satisfied: llama-index-cli<0.5.0,>=0.4.0 in .\testenv\lib\site-packages (from llama_index) (0.4.0)
# Requirement already satisfied: llama-index-core<0.13.0,>=0.12.5 in .\testenv\lib\site-packages (from llama_index) (0.12.5)
# Requirement already satisfied: llama-index-embeddings-openai<0.4.0,>=0.3.0 in .\testenv\lib\site-packages (from llama_index) (0.3.1)
# Requirement already satisfied: llama-index-indices-managed-llama-cloud>=0.4.0 in .\testenv\lib\site-packages (from llama_index) (0.6.3)
# Requirement already satisfied: llama-index-legacy<0.10.0,>=0.9.48 in .\testenv\lib\site-packages (from llama_index) (0.9.48.post4)
# Requirement already satisfied: llama-index-llms-openai<0.4.0,>=0.3.0 in .\testenv\lib\site-packages (from llama_index) (0.3.10)
# Requirement already satisfied: llama-index-multi-modal-llms-openai<0.5.0,>=0.4.0 in .\testenv\lib\site-packages (from llama_index) (0.4.0)
# Requirement already satisfied: llama-index-program-openai<0.4.0,>=0.3.0 in .\testenv\lib\site-packages (from llama_index) (0.3.1)
# Requirement already satisfied: llama-index-question-gen-openai<0.4.0,>=0.3.0 in .\testenv\lib\site-packages (from llama_index) (0.3.0)
# Requirement already satisfied: llama-index-readers-file<0.5.0,>=0.4.0 in .\testenv\lib\site-packages (from llama_index) (0.4.1)
# Requirement already satisfied: llama-index-readers-llama-parse>=0.4.0 in .\testenv\lib\site-packages (from llama_index) (0.4.0)
# Requirement already satisfied: nltk>3.8.1 in .\testenv\lib\site-packages (from llama_index) (3.9.1)
# Requirement already satisfied: openai>=1.14.0 in .\testenv\lib\site-packages (from llama-index-agent-openai<0.5.0,>=0.4.0->llama_index) (1.57.4)
# Requirement already satisfied: PyYAML>=6.0.1 in .\testenv\lib\site-packages (from llama-index-core<0.13.0,>=0.12.5->llama_index) (6.0.2)
# Requirement already satisfied: SQLAlchemy>=1.4.49 in .\testenv\lib\site-packages (from SQLAlchemy[asyncio]>=1.4.49->llama-index-core<0.13.0,>=0.12.5->llama_index) (2.0.36)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.6 in .\testenv\lib\site-packages (from llama-index-core<0.13.0,>=0.12.5->llama_index) (3.11.10)
# Requirement already satisfied: dataclasses-json in .\testenv\lib\site-packages (from llama-index-core<0.13.0,>=0.12.5->llama_index) (0.6.7)
# Requirement already satisfied: deprecated>=1.2.9.3 in .\testenv\lib\site-packages (from llama-index-core<0.13.0,>=0.12.5->llama_index) (1.2.15)
# Requirement already satisfied: dirtyjson<2.0.0,>=1.0.8 in .\testenv\lib\site-packages (from llama-index-core<0.13.0,>=0.12.5->llama_index) (1.0.8)
# Requirement already satisfied: filetype<2.0.0,>=1.2.0 in .\testenv\lib\site-packages (from llama-index-core<0.13.0,>=0.12.5->llama_index) (1.2.0)
# Requirement already satisfied: fsspec>=2023.5.0 in .\testenv\lib\site-packages (from llama-index-core<0.13.0,>=0.12.5->llama_index) (2024.10.0)
# Requirement already satisfied: httpx in .\testenv\lib\site-packages (from llama-index-core<0.13.0,>=0.12.5->llama_index) (0.27.2)
# Requirement already satisfied: nest-asyncio<2.0.0,>=1.5.8 in .\testenv\lib\site-packages (from llama-index-core<0.13.0,>=0.12.5->llama_index) (1.6.0)
# Requirement already satisfied: networkx>=3.0 in .\testenv\lib\site-packages (from llama-index-core<0.13.0,>=0.12.5->llama_index) (3.4.2)
# Requirement already satisfied: numpy in .\testenv\lib\site-packages (from llama-index-core<0.13.0,>=0.12.5->llama_index) (1.26.4)
# Requirement already satisfied: pillow>=9.0.0 in .\testenv\lib\site-packages (from llama-index-core<0.13.0,>=0.12.5->llama_index) (11.0.0)
# Requirement already satisfied: pydantic>=2.8.0 in .\testenv\lib\site-packages (from llama-index-core<0.13.0,>=0.12.5->llama_index) (2.10.3)
# Requirement already satisfied: requests>=2.31.0 in .\testenv\lib\site-packages (from llama-index-core<0.13.0,>=0.12.5->llama_index) (2.32.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.2.0 in .\testenv\lib\site-packages (from llama-index-core<0.13.0,>=0.12.5->llama_index) (8.5.0)
# Requirement already satisfied: tiktoken>=0.3.3 in .\testenv\lib\site-packages (from llama-index-core<0.13.0,>=0.12.5->llama_index) (0.8.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.66.1 in .\testenv\lib\site-packages (from llama-index-core<0.13.0,>=0.12.5->llama_index) (4.67.1)
# Requirement already satisfied: typing-extensions>=4.5.0 in .\testenv\lib\site-packages (from llama-index-core<0.13.0,>=0.12.5->llama_index) (4.12.2)
# Requirement already satisfied: typing-inspect>=0.8.0 in .\testenv\lib\site-packages (from llama-index-core<0.13.0,>=0.12.5->llama_index) (0.9.0)
# Requirement already satisfied: wrapt in .\testenv\lib\site-packages (from llama-index-core<0.13.0,>=0.12.5->llama_index) (1.17.0)
# Requirement already satisfied: llama-cloud>=0.1.5 in .\testenv\lib\site-packages (from llama-index-indices-managed-llama-cloud>=0.4.0->llama_index) (0.1.6)
# Requirement already satisfied: pandas in .\testenv\lib\site-packages (from llama-index-legacy<0.10.0,>=0.9.48->llama_index) (2.2.3)
# Requirement already satisfied: beautifulsoup4<5.0.0,>=4.12.3 in .\testenv\lib\site-packages (from llama-index-readers-file<0.5.0,>=0.4.0->llama_index) (4.12.3)
# Requirement already satisfied: pypdf<6.0.0,>=5.1.0 in .\testenv\lib\site-packages (from llama-index-readers-file<0.5.0,>=0.4.0->llama_index) (5.1.0)
# Requirement already satisfied: striprtf<0.0.27,>=0.0.26 in .\testenv\lib\site-packages (from llama-index-readers-file<0.5.0,>=0.4.0->llama_index) (0.0.26)
# Requirement already satisfied: llama-parse>=0.5.0 in .\testenv\lib\site-packages (from llama-index-readers-llama-parse>=0.4.0->llama_index) (0.5.17)
# Requirement already satisfied: click in .\testenv\lib\site-packages (from nltk>3.8.1->llama_index) (8.1.7)
# Requirement already satisfied: joblib in .\testenv\lib\site-packages (from nltk>3.8.1->llama_index) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in .\testenv\lib\site-packages (from nltk>3.8.1->llama_index) (2024.11.6)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in .\testenv\lib\site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.13.0,>=0.12.5->llama_index) (2.4.4)
# Requirement already satisfied: aiosignal>=1.1.2 in .\testenv\lib\site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.13.0,>=0.12.5->llama_index) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in .\testenv\lib\site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.13.0,>=0.12.5->llama_index) (24.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in .\testenv\lib\site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.13.0,>=0.12.5->llama_index) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in .\testenv\lib\site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.13.0,>=0.12.5->llama_index) (6.1.0)
# Requirement already satisfied: propcache>=0.2.0 in .\testenv\lib\site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.13.0,>=0.12.5->llama_index) (0.2.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in .\testenv\lib\site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.13.0,>=0.12.5->llama_index) (1.18.3)
# Requirement already satisfied: soupsieve>1.2 in .\testenv\lib\site-packages (from beautifulsoup4<5.0.0,>=4.12.3->llama-index-readers-file<0.5.0,>=0.4.0->llama_index) (2.6)
# Requirement already satisfied: anyio in .\testenv\lib\site-packages (from httpx->llama-index-core<0.13.0,>=0.12.5->llama_index) (4.7.0)
# Requirement already satisfied: certifi in .\testenv\lib\site-packages (from httpx->llama-index-core<0.13.0,>=0.12.5->llama_index) (2024.12.14)
# Requirement already satisfied: httpcore==1.* in .\testenv\lib\site-packages (from httpx->llama-index-core<0.13.0,>=0.12.5->llama_index) (1.0.7)
# Requirement already satisfied: idna in .\testenv\lib\site-packages (from httpx->llama-index-core<0.13.0,>=0.12.5->llama_index) (3.10)
# Requirement already satisfied: sniffio in .\testenv\lib\site-packages (from httpx->llama-index-core<0.13.0,>=0.12.5->llama_index) (1.3.1)
# Requirement already satisfied: h11<0.15,>=0.13 in .\testenv\lib\site-packages (from httpcore==1.*->httpx->llama-index-core<0.13.0,>=0.12.5->llama_index) (0.14.0)
# Requirement already satisfied: colorama in .\testenv\lib\site-packages (from click->nltk>3.8.1->llama_index) (0.4.6)
# Requirement already satisfied: distro<2,>=1.7.0 in .\testenv\lib\site-packages (from openai>=1.14.0->llama-index-agent-openai<0.5.0,>=0.4.0->llama_index) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.4.0 in .\testenv\lib\site-packages (from openai>=1.14.0->llama-index-agent-openai<0.5.0,>=0.4.0->llama_index) (0.8.2)
# Requirement already satisfied: annotated-types>=0.6.0 in .\testenv\lib\site-packages (from pydantic>=2.8.0->llama-index-core<0.13.0,>=0.12.5->llama_index) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.1 in .\testenv\lib\site-packages (from pydantic>=2.8.0->llama-index-core<0.13.0,>=0.12.5->llama_index) (2.27.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in .\testenv\lib\site-packages (from requests>=2.31.0->llama-index-core<0.13.0,>=0.12.5->llama_index) (3.4.0)
# Requirement already satisfied: urllib3<3,>=1.21.1 in .\testenv\lib\site-packages (from requests>=2.31.0->llama-index-core<0.13.0,>=0.12.5->llama_index) (2.2.3)
# Requirement already satisfied: greenlet!=0.4.17 in .\testenv\lib\site-packages (from SQLAlchemy>=1.4.49->SQLAlchemy[asyncio]>=1.4.49->llama-index-core<0.13.0,>=0.12.5->llama_index) (3.1.1)
# Requirement already satisfied: mypy-extensions>=0.3.0 in .\testenv\lib\site-packages (from typing-inspect>=0.8.0->llama-index-core<0.13.0,>=0.12.5->llama_index) (1.0.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in .\testenv\lib\site-packages (from dataclasses-json->llama-index-core<0.13.0,>=0.12.5->llama_index) (3.23.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in .\testenv\lib\site-packages (from pandas->llama-index-legacy<0.10.0,>=0.9.48->llama_index) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in .\testenv\lib\site-packages (from pandas->llama-index-legacy<0.10.0,>=0.9.48->llama_index) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in .\testenv\lib\site-packages (from pandas->llama-index-legacy<0.10.0,>=0.9.48->llama_index) (2024.2)
# Requirement already satisfied: packaging>=17.0 in .\testenv\lib\site-packages (from marshmallow<4.0.0,>=3.18.0->dataclasses-json->llama-index-core<0.13.0,>=0.12.5->llama_index) (24.2)
# Requirement already satisfied: six>=1.5 in .\testenv\lib\site-packages (from python-dateutil>=2.8.2->pandas->llama-index-legacy<0.10.0,>=0.9.48->llama_index) (1.17.0)
# [notice] A new release of pip is available: 24.2 -> 24.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
