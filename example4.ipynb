# %%
from dotenv import load_dotenv
load_dotenv()
import os

# %%
from langchain_openai import ChatOpenAI
import requests
from pydantic import BaseModel, Field
from langchain_core.prompts import PromptTemplate
from langchain_core.output_parsers import JsonOutputParser
import re

llm = ChatOpenAI(
    model='gpt-4o-mini',
    base_url= os.getenv("url"),  
    api_key= os.getenv("api_key"),  
    max_tokens=1000 
)

# User location and search radius
user_location = (13.7563, 100.5018)  # Example: Bangkok
radius = 5  # Radius in kilometers

# %%
# สร้างโมเดล Pydantic สำหรับการจัดการข้อมูลคำสำคัญที่ได้จาก LLM
class SearchKeyword(BaseModel):
    keyword: str = Field(description="คำสำคัญที่ได้จากการประมวลผลคำถาม") # เพิ่มเรืองการ promt

# Clean keyword function
def clean_keyword(keyword: str) -> str:
    unwanted_words = ["แถวนี้", "ใกล้ฉัน", "ใกล้", "ช่วยหา"]
    for word in unwanted_words:
        keyword = keyword.replace(word, "")
    return re.sub(r'\s+', ' ', keyword).strip()

# Search function for Logdo Map API
def search_logdo_map_api(keyword, user_location, radius):
    base_url = "https://search.longdo.com/mapsearch/json/search?"
    params = {
        'keyword': keyword,
        'lon': user_location[1],
        'lat': user_location[0],
        'span': radius,
        'locale': 'th',
        'key': os.getenv("key_longdo")
    }
    response = requests.get(base_url, params=params)
    return response.json() if response.status_code == 200 else None

# Process user query
def process_user_query(user_query, user_location, radius):
    # Parse keyword from LLM
    parser = JsonOutputParser(pydantic_object=SearchKeyword)
    prompt = PromptTemplate(
        template="""\
## คุณมีหน้าที่กรองคำสำคัญจากคำขอผู้ใช้. # เพิ่มเรืองการ promt

# คำขอผู้ใช้: {user_query}

# Your response should be structured as follows:
{format_instructions}
""",
        input_variables=["user_query"],
        partial_variables={"format_instructions": parser.get_format_instructions()},
    )
    chain = prompt | llm | parser
    event = chain.invoke({"user_query": user_query, "user_location": user_location})

    if event:
        keyword = event.get('keyword', '')
        cleaned_keyword = clean_keyword(keyword)
        if cleaned_keyword:
            places_from_api = search_logdo_map_api(cleaned_keyword, user_location, radius)
            return cleaned_keyword, places_from_api
    return None, None

# %%
user_query = "บอกรายชื่อเซเว่นแถวนี้ให้หน่อย"
print(f"คำขอผู้ใช้: {user_query}")
print(f"ตำแหน่งผู้ใช้: {user_location}")
print(f"รัศมี: {radius} กิโลเมตร")
# Out:
# คำขอผู้ใช้: บอกรายชื่อเซเว่นแถวนี้ให้หน่อย
# ตำแหน่งผู้ใช้: (13.7563, 100.5018)
# รัศมี: 5 กิโลเมตร

# %%
keyword, places_from_api = process_user_query(user_query, user_location, radius)

if keyword:
    print(f"คำค้นหา: {keyword}")
    if places_from_api and "data" in places_from_api:
        print("รายชื่อสถานที่:")
        for place in places_from_api["data"]:
            print(place.get("name", "ไม่ทราบชื่อ"))
    else:
        print("ไม่พบข้อมูลสถานที่ในผลลัพธ์")
else:
    print("ไม่พบคำสำคัญจากการประมวลผล")
# Out:
# คำค้นหา: เซเว่น
# รายชื่อสถานที่:
# เซเว่นอิเลฟเว่น ถนนดินสอ จุด 3 (รหัสสาขา: 13597)
# เซเว่นอีเลฟเว่น
# เซเว่นอิเลฟเว่น ถนนดินสอ จุด 2 (รหัสสาขา: 09797)
# เซเว่นอิเลฟเว่น ถนนดินสอ (รหัสสาขา: 00117)
# เซเว่นอีเลฟเว่น
# เซเว่นอีเลฟเว่น
# เซเว่นอีเลฟเว่น ราชดำเนิน (รหัสสาขา: 00216)
# เซเว่นอีเลฟเว่น
# เซเว่นอีเลฟเว่น ราชดำเนิน 3 (รหัสสาขา: 01102)
# เซเว่นอิเลฟเว่น ตรอกมหรรณพาราม (รหัสสาขา: 15076)
# เซเว่นอิเลฟเว่น สะพานวันชาติ (รหัสสาขา: 04217)
# เซเว่นอีเลฟเว่น
# เซเว่นอิเลฟเว่น ถนนราชดำเนินกลาง (รหัสสาขา: 10866)
# เซเว่นอิเลฟเว่น Booth ตะนาว (รหัสสาขา: 00585)
# เซเว่นอีเลฟเว่น
# เซเว่นอิเลฟเว่น ถนนมหรรณพ (รหัสสาขา: 04249)
# เซเว่นอิเลฟเว่น Booth ข้าวสาร (รหัสสาขา: 01355)
# เซเว่นอีเลฟเว่น ตรอกข้าวสาร (รหัสสาขา: 01777)
# เซเว่นอีเลฟเว่น
# เซเว่นอิเลฟเว่น บางลำภู 4 (รหัสสาขา: 17222)

# %%
import folium
from IPython.display import display, HTML
import ipywidgets as widgets
import requests

# ฟังก์ชันสร้างแผนที่พร้อมเส้นทาง
def create_map_with_route(route_data, start_coords, end_coords):
    route_map = folium.Map(location=start_coords, zoom_start=15)

    # เพิ่มจุดเริ่มต้นและปลายทาง
    folium.Marker(start_coords, popup="จุดเริ่มต้น", icon=folium.Icon(color="green")).add_to(route_map)
    folium.Marker(end_coords, popup="จุดปลายทาง", icon=folium.Icon(color="red")).add_to(route_map)

    # ตรวจสอบว่ามีข้อมูล guide หรือไม่
    for route in route_data.get("data", []):
        guides = route.get("guide", [])
        if guides:
            for i, guide in enumerate(guides):
                folium.Marker(
                    start_coords,  # ใช้จุดเริ่มต้นเพื่อแทนที่ตำแหน่งจริง (ถ้าพิกัดไม่มี)
                    popup=f"จุดที่ {i+1}: {guide['name']} ({guide['distance']} เมตร)",
                    icon=folium.Icon(color="blue", icon="info-sign")
                ).add_to(route_map)

    # วาดเส้นระหว่างจุดเริ่มต้นและปลายทาง
    folium.PolyLine([start_coords, end_coords], color="blue", weight=5, opacity=0.7).add_to(route_map)
    return route_map

# ฟังก์ชันแสดงแผนที่
def display_route_map(route_info, user_location, destination_coords):
    print("\nข้อมูลเส้นทาง:")
    print(route_info)

    print("\nกำลังสร้างแผนที่...")
    route_map = create_map_with_route(route_info, user_location, destination_coords)
    route_map_html = route_map._repr_html_()
    display(HTML(route_map_html))

# ฟังก์ชันแสดง Dropdown สำหรับเลือกสถานที่
def display_places_list(places_from_api, user_location):
    if places_from_api and "data" in places_from_api:
        places = places_from_api["data"]

        # สร้างตัวเลือก Dropdown พร้อมพิกัดละติจูดและลองจิจูดจากสถานที่
        options = [(place.get("name", "ไม่ทราบชื่อ"), (place.get("lat"), place.get("lon"))) for place in places]
        dropdown = widgets.Dropdown(
            options=options,
            description='สถานที่:',
            value=options[0][1] if options else None
        )

        # ฟังก์ชันเมื่อเปลี่ยนค่าของ Dropdown
        def on_dropdown_change(change):
            selected_coords = change.new
            if selected_coords:
                dest_lat, dest_lon = selected_coords
                print(f"\nคุณเลือกสถานที่: {dropdown.label}")
                print(f"ละติจูด: {dest_lat}, ลองจิจูด: {dest_lon}")

                # ดึงข้อมูลเส้นทาง
                print("\nกำลังดึงข้อมูลเส้นทาง...")
                # เรียกใช้ฟังก์ชัน get_route โดยใช้พิกัดที่เลือก
                route_info = get_route(user_location[0], user_location[1], dest_lat, dest_lon)
                if route_info:
                    display_route_map(route_info, user_location, (dest_lat, dest_lon))
                else:
                    print("ไม่สามารถดึงข้อมูลเส้นทางได้")

        # ตั้งค่าการทำงานเมื่อมีการเลือกสถานที่
        dropdown.observe(on_dropdown_change, names='value')

        # แสดง Dropdown
        display(dropdown)
    else:
        print("ไม่พบข้อมูลสถานที่ในผลลัพธ์")

# ฟังก์ชันที่ดึงข้อมูลเส้นทาง
def get_route(user_lat, user_lon, dest_lat, dest_lon):
    url = "https://api.longdo.com/RouteService/json/route/guide?"
    params = {
        "flon": user_lon,  # ลองจิจูดของผู้ใช้
        "flat": user_lat,  # ละติจูดของผู้ใช้
        "tlon": dest_lon,  # ลองจิจูดของปลายทาง
        "tlat": dest_lat,  # ละติจูดของปลายทาง
        "mode": "t",  # โมเดลการเดินทาง
        "restrict": 0,
        "locale": "th",
        'key': os.getenv("key_longdo")  # ใช้ API Key จริง
    }

    try:
        response = requests.get(url, params=params)
        
        # ตรวจสอบว่า API ส่งสถานะ 200 (OK) หรือไม่
        if response.status_code == 200:
            data = response.json()
            if "data" in data:
                return data
            else:
                print(f"ข้อมูลเส้นทางไม่พบในผลลัพธ์: {data}")
                return None
        else:
            print(f"เกิดข้อผิดพลาดจาก API: {response.status_code}, Message: {response.text}")
            return None
    except Exception as e:
        print(f"เกิดข้อผิดพลาดในการเชื่อมต่อ API: {e}")
        return None

# ฟังก์ชันประมวลผลคำถามผู้ใช้และค้นหาสถานที่
# (สมมติว่ามีฟังก์ชัน `process_user_query` อยู่แล้ว)
keyword, places_from_api = process_user_query(user_query, user_location, radius)

if keyword:
    print(f"คำค้นหา: {keyword}")
    if places_from_api and "data" in places_from_api:
        print("\nรายชื่อสถานที่:")
        display_places_list(places_from_api, user_location)
    else:
        print("\nไม่พบข้อมูลสถานที่ในผลลัพธ์")
else:
    print("\nไม่พบคำสำคัญจากการประมวลผล")
# Out:
# คำค้นหา: เซเว่น
#
# รายชื่อสถานที่:
# Dropdown(description='สถานที่:', options=(('เซเว่นอิเลฟเว่น ถนนดินสอ จุด 3 (รหัสสาขา: 13597)', (13.75523416, 1…
# คุณเลือกสถานที่: เซเว่นอิเลฟเว่น Booth ตะนาว (รหัสสาขา: 00585)
# ละติจูด: 13.754489, ลองจิจูด: 100.498435
#
# กำลังดึงข้อมูลเส้นทาง...
#
# ข้อมูลเส้นทาง:
# {'meta': {'status': 200, 'from': {'lon': 100.5018, 'lat': 13.7563}, 'to': {'lon': 100.498435, 'lat': 13.754489}, 'config': 'tnullth0'}, 'data': [{'guide': [{'turn': 4, 'name': 'วงเวียนอนุสาวรีย์ประชาธิปไตย', 'distance': 39, 'interval': 10}, {'turn': 2, 'name': 'ถนนราชดำเนินกลาง', 'distance': 135, 'interval': 28}, {'turn': 0, 'name': 'ถนนเชื่อมต่อ', 'distance': 55, 'interval': 10}, {'turn': 1, 'name': 'ซอยดำเนินกลางใต้', 'distance': 129, 'interval': 23}, {'turn': 0, 'name': 'ถนนเชื่อมต่อ', 'distance': 104, 'interval': 19}, {'turn': 0, 'name': 'ถนนตะนาว', 'distance': 151, 'interval': 59}, {'turn': 1, 'name': 'ถนนบุญศิริ', 'distance': 15, 'interval': 6}], 'fdistance': 0.9496057, 'tdistance': 7.2220855, 'distance': 628, 'interval': 155, 'penalty': 105, 'id': 31556166}]}
#
# กำลังสร้างแผนที่...
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b2176d0a5fd76ad3481751f1c1a5a2b6 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b2176d0a5fd76ad3481751f1c1a5a2b6&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_b2176d0a5fd76ad3481751f1c1a5a2b6 = L.map(
#                 &quot;map_b2176d0a5fd76ad3481751f1c1a5a2b6&quot;,
#                 {
#                     center: [13.7563, 100.5018],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 15,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_632c106660c70b895177629cd2ee96df = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_632c106660c70b895177629cd2ee96df.addTo(map_b2176d0a5fd76ad3481751f1c1a5a2b6);
#
#
#             var marker_cea4a7e346dffe2efdc94cda3711155c = L.marker(
#                 [13.7563, 100.5018],
#                 {
# }
#             ).addTo(map_b2176d0a5fd76ad3481751f1c1a5a2b6);
#
#
#             var icon_ab28690cbe07128b3692e3eafd241a69 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;green&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#             marker_cea4a7e346dffe2efdc94cda3711155c.setIcon(icon_ab28690cbe07128b3692e3eafd241a69);
#
#
#         var popup_5d0ae3be173869606c09a81f1e059bdb = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d2a02afaef6c82124747148aa8d3371a = $(`&lt;div id=&quot;html_d2a02afaef6c82124747148aa8d3371a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;จุดเริ่มต้น&lt;/div&gt;`)[0];
#                 popup_5d0ae3be173869606c09a81f1e059bdb.setContent(html_d2a02afaef6c82124747148aa8d3371a);
#
#
#
#         marker_cea4a7e346dffe2efdc94cda3711155c.bindPopup(popup_5d0ae3be173869606c09a81f1e059bdb)
#         ;
#
#
#
#
#             var marker_2d437f344298ae8e2de2f90c28fb0006 = L.marker(
#                 [13.754489, 100.498435],
#                 {
# }
#             ).addTo(map_b2176d0a5fd76ad3481751f1c1a5a2b6);
#
#
#             var icon_c69b405e626613d0c6d736a64f74287d = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;red&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#             marker_2d437f344298ae8e2de2f90c28fb0006.setIcon(icon_c69b405e626613d0c6d736a64f74287d);
#
#
#         var popup_408de44ae540356805cdde92643dc7bc = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_34932afef1ac4cc154d58fc17e8146ce = $(`&lt;div id=&quot;html_34932afef1ac4cc154d58fc17e8146ce&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;จุดปลายทาง&lt;/div&gt;`)[0];
#                 popup_408de44ae540356805cdde92643dc7bc.setContent(html_34932afef1ac4cc154d58fc17e8146ce);
#
#
#
#         marker_2d437f344298ae8e2de2f90c28fb0006.bindPopup(popup_408de44ae540356805cdde92643dc7bc)
#         ;
#
#
#
#
#             var marker_252ce0a7b6f93da07715150c8be1da41 = L.marker(
#                 [13.7563, 100.5018],
#                 {
# }
#             ).addTo(map_b2176d0a5fd76ad3481751f1c1a5a2b6);
#
#
#             var icon_55f15abcc7f705c2965bcbb7a68f5808 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;blue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#             marker_252ce0a7b6f93da07715150c8be1da41.setIcon(icon_55f15abcc7f705c2965bcbb7a68f5808);
#
#
#         var popup_b2dc3c99a5c4de31873a16215bb93505 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a4d1e1955a9af7460af53bb350fe5646 = $(`&lt;div id=&quot;html_a4d1e1955a9af7460af53bb350fe5646&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;จุดที่ 1: วงเวียนอนุสาวรีย์ประชาธิปไตย (39 เมตร)&lt;/div&gt;`)[0];
#                 popup_b2dc3c99a5c4de31873a16215bb93505.setContent(html_a4d1e1955a9af7460af53bb350fe5646);
#
#
#
#         marker_252ce0a7b6f93da07715150c8be1da41.bindPopup(popup_b2dc3c99a5c4de31873a16215bb93505)
#         ;
#
#
#
#
#             var marker_9026b6899dbccb7fa5e302cecf1cd7d5 = L.marker(
#                 [13.7563, 100.5018],
#                 {
# }
#             ).addTo(map_b2176d0a5fd76ad3481751f1c1a5a2b6);
#
#
#             var icon_f03ba28a10819da9d6a6dedcc600128d = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &
# คุณเลือกสถานที่: เซเว่นอิเลฟเว่น ตรอกมหรรณพาราม (รหัสสาขา: 15076)
# ละติจูด: 13.7536271, ลองจิจูด: 100.50014747
#
# กำลังดึงข้อมูลเส้นทาง...
#
# ข้อมูลเส้นทาง:
# {'meta': {'status': 200, 'from': {'lon': 100.5018, 'lat': 13.7563}, 'to': {'lon': 100.50014747, 'lat': 13.7536271}, 'config': 'tnullth0'}, 'data': [{'guide': [{'turn': 4, 'name': 'วงเวียนอนุสาวรีย์ประชาธิปไตย', 'distance': 39, 'interval': 10}, {'turn': 2, 'name': 'ถนนราชดำเนินกลาง', 'distance': 135, 'interval': 28}, {'turn': 0, 'name': 'ถนนเชื่อมต่อ', 'distance': 55, 'interval': 10}, {'turn': 0, 'name': 'ซอยดำเนินกลางใต้', 'distance': 60, 'interval': 11}, {'turn': 1, 'name': 'ถนนเชื่อมต่อ', 'distance': 144, 'interval': 25}, {'turn': 0, 'name': 'ตรอกศิลป์', 'distance': 71, 'interval': 13}, {'turn': 1, 'name': 'ถนนดินสอ', 'distance': 179, 'interval': 54}, {'turn': 1, 'name': 'ถนนมหรรณพ', 'distance': 107, 'interval': 47}], 'fdistance': 0.9496057, 'tdistance': 9.430536, 'distance': 790, 'interval': 198, 'penalty': 120, 'id': 31556174}]}
#
# กำลังสร้างแผนที่...
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_16e9e0eaae24a4da1f36ef684bc44f95 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_16e9e0eaae24a4da1f36ef684bc44f95&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_16e9e0eaae24a4da1f36ef684bc44f95 = L.map(
#                 &quot;map_16e9e0eaae24a4da1f36ef684bc44f95&quot;,
#                 {
#                     center: [13.7563, 100.5018],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 15,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_fed49459bdad783c8fcc040eab3d2fd1 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_fed49459bdad783c8fcc040eab3d2fd1.addTo(map_16e9e0eaae24a4da1f36ef684bc44f95);
#
#
#             var marker_44a6e34b5591aa660e8c0b08b3c29318 = L.marker(
#                 [13.7563, 100.5018],
#                 {
# }
#             ).addTo(map_16e9e0eaae24a4da1f36ef684bc44f95);
#
#
#             var icon_ea9c5d453aeeca0a7c2c38acecf64e16 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;green&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#             marker_44a6e34b5591aa660e8c0b08b3c29318.setIcon(icon_ea9c5d453aeeca0a7c2c38acecf64e16);
#
#
#         var popup_15deec9a251743560ec664f0a4375b21 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e8ea2b3d970cbcaf57d3553d12611348 = $(`&lt;div id=&quot;html_e8ea2b3d970cbcaf57d3553d12611348&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;จุดเริ่มต้น&lt;/div&gt;`)[0];
#                 popup_15deec9a251743560ec664f0a4375b21.setContent(html_e8ea2b3d970cbcaf57d3553d12611348);
#
#
#
#         marker_44a6e34b5591aa660e8c0b08b3c29318.bindPopup(popup_15deec9a251743560ec664f0a4375b21)
#         ;
#
#
#
#
#             var marker_1bfed9abae0db0347ac6938d6bddb9fd = L.marker(
#                 [13.7536271, 100.50014747],
#                 {
# }
#             ).addTo(map_16e9e0eaae24a4da1f36ef684bc44f95);
#
#
#             var icon_e65762a6bb1c803ef23e0a0b029baace = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;red&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#             marker_1bfed9abae0db0347ac6938d6bddb9fd.setIcon(icon_e65762a6bb1c803ef23e0a0b029baace);
#
#
#         var popup_8c96de907fac1f100db556e15117788a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a491f2a2850c74b86df1e6cebad59037 = $(`&lt;div id=&quot;html_a491f2a2850c74b86df1e6cebad59037&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;จุดปลายทาง&lt;/div&gt;`)[0];
#                 popup_8c96de907fac1f100db556e15117788a.setContent(html_a491f2a2850c74b86df1e6cebad59037);
#
#
#
#         marker_1bfed9abae0db0347ac6938d6bddb9fd.bindPopup(popup_8c96de907fac1f100db556e15117788a)
#         ;
#
#
#
#
#             var marker_9b1799ab738f80d3373f01b2b7954053 = L.marker(
#                 [13.7563, 100.5018],
#                 {
# }
#             ).addTo(map_16e9e0eaae24a4da1f36ef684bc44f95);
#
#
#             var icon_db364c3297546bc89666add9f1aa6faf = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;blue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#             marker_9b1799ab738f80d3373f01b2b7954053.setIcon(icon_db364c3297546bc89666add9f1aa6faf);
#
#
#         var popup_75975d87c324eaddd1a4f82a8c514cf6 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_974a7d65e50475884aebcfa56c5ce785 = $(`&lt;div id=&quot;html_974a7d65e50475884aebcfa56c5ce785&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;จุดที่ 1: วงเวียนอนุสาวรีย์ประชาธิปไตย (39 เมตร)&lt;/div&gt;`)[0];
#                 popup_75975d87c324eaddd1a4f82a8c514cf6.setContent(html_974a7d65e50475884aebcfa56c5ce785);
#
#
#
#         marker_9b1799ab738f80d3373f01b2b7954053.bindPopup(popup_75975d87c324eaddd1a4f82a8c514cf6)
#         ;
#
#
#
#
#             var marker_f04f2b045788afbffed93b4282719c86 = L.marker(
#                 [13.7563, 100.5018],
#                 {
# }
#             ).addTo(map_16e9e0eaae24a4da1f36ef684bc44f95);
#
#
#             var icon_f1525ca42cd6a2b5d03f6bf4094a486e = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;
# คุณเลือกสถานที่: เซเว่นอิเลฟเว่น ถนนดินสอ จุด 2 (รหัสสาขา: 09797)
# ละติจูด: 13.757852, ลองจิจูด: 100.502241
#
# กำลังดึงข้อมูลเส้นทาง...
#
# ข้อมูลเส้นทาง:
# {'meta': {'status': 200, 'from': {'lon': 100.5018, 'lat': 13.7563}, 'to': {'lon': 100.502241, 'lat': 13.757852}, 'config': 'tnullth0'}, 'data': [{'guide': [{'turn': 4, 'name': 'วงเวียนอนุสาวรีย์ประชาธิปไตย', 'distance': 111, 'interval': 30}, {'turn': 2, 'name': 'ถนนดินสอ', 'distance': 106, 'interval': 9}], 'fdistance': 0.9496057, 'tdistance': 10.145972, 'distance': 217, 'interval': 39, 'penalty': 30, 'id': 39807313}]}
#
# กำลังสร้างแผนที่...
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_1f7d985d5b0ae1fe78971bff01ac798f {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_1f7d985d5b0ae1fe78971bff01ac798f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_1f7d985d5b0ae1fe78971bff01ac798f = L.map(
#                 &quot;map_1f7d985d5b0ae1fe78971bff01ac798f&quot;,
#                 {
#                     center: [13.7563, 100.5018],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 15,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_161b83eedd6f7ba325533831b4f811aa = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_161b83eedd6f7ba325533831b4f811aa.addTo(map_1f7d985d5b0ae1fe78971bff01ac798f);
#
#
#             var marker_1d419db129533c4dc53478e939f2eda5 = L.marker(
#                 [13.7563, 100.5018],
#                 {
# }
#             ).addTo(map_1f7d985d5b0ae1fe78971bff01ac798f);
#
#
#             var icon_54ffe897021b80095a252703cfc3f35d = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;green&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#             marker_1d419db129533c4dc53478e939f2eda5.setIcon(icon_54ffe897021b80095a252703cfc3f35d);
#
#
#         var popup_bab9791dac7385effc8f3751a7d3f3ff = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d1fa610ac2d469c1ecf0ffa992fe62c4 = $(`&lt;div id=&quot;html_d1fa610ac2d469c1ecf0ffa992fe62c4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;จุดเริ่มต้น&lt;/div&gt;`)[0];
#                 popup_bab9791dac7385effc8f3751a7d3f3ff.setContent(html_d1fa610ac2d469c1ecf0ffa992fe62c4);
#
#
#
#         marker_1d419db129533c4dc53478e939f2eda5.bindPopup(popup_bab9791dac7385effc8f3751a7d3f3ff)
#         ;
#
#
#
#
#             var marker_b9aee5e5a4ce9ddf6e1fe7d9d9c0fc96 = L.marker(
#                 [13.757852, 100.502241],
#                 {
# }
#             ).addTo(map_1f7d985d5b0ae1fe78971bff01ac798f);
#
#
#             var icon_306479bce094f4529c207e4a807fd42a = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;red&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#             marker_b9aee5e5a4ce9ddf6e1fe7d9d9c0fc96.setIcon(icon_306479bce094f4529c207e4a807fd42a);
#
#
#         var popup_a52f2d01af6e139a071e3cb9e4888ed8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b42df873cfbfc6384034d34965e4eddd = $(`&lt;div id=&quot;html_b42df873cfbfc6384034d34965e4eddd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;จุดปลายทาง&lt;/div&gt;`)[0];
#                 popup_a52f2d01af6e139a071e3cb9e4888ed8.setContent(html_b42df873cfbfc6384034d34965e4eddd);
#
#
#
#         marker_b9aee5e5a4ce9ddf6e1fe7d9d9c0fc96.bindPopup(popup_a52f2d01af6e139a071e3cb9e4888ed8)
#         ;
#
#
#
#
#             var marker_7f7d9f43a59f8bbe125bc6f2515484ac = L.marker(
#                 [13.7563, 100.5018],
#                 {
# }
#             ).addTo(map_1f7d985d5b0ae1fe78971bff01ac798f);
#
#
#             var icon_caa9e4c1cc606aecad6fa3ac65c64b01 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;blue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#             marker_7f7d9f43a59f8bbe125bc6f2515484ac.setIcon(icon_caa9e4c1cc606aecad6fa3ac65c64b01);
#
#
#         var popup_0bf40baa4c10ad429309115638995c4c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e33a6228c2d15ea0a38e67b63bcdbb0f = $(`&lt;div id=&quot;html_e33a6228c2d15ea0a38e67b63bcdbb0f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;จุดที่ 1: วงเวียนอนุสาวรีย์ประชาธิปไตย (111 เมตร)&lt;/div&gt;`)[0];
#                 popup_0bf40baa4c10ad429309115638995c4c.setContent(html_e33a6228c2d15ea0a38e67b63bcdbb0f);
#
#
#
#         marker_7f7d9f43a59f8bbe125bc6f2515484ac.bindPopup(popup_0bf40baa4c10ad429309115638995c4c)
#         ;
#
#
#
#
#             var marker_bc2339ab26e1229a8848ab216d17fbe0 = L.marker(
#                 [13.7563, 100.5018],
#                 {
# }
#             ).addTo(map_1f7d985d5b0ae1fe78971bff01ac798f);
#
#
#             var icon_58d6a3587ee10bcdfdaed767fbc0bcc2 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;:
# คุณเลือกสถานที่: เซเว่นอิเลฟเว่น บางลำภู 4 (รหัสสาขา: 17222)
# ละติจูด: 13.75976719, ลองจิจูด: 100.49904531
#
# กำลังดึงข้อมูลเส้นทาง...
#
# ข้อมูลเส้นทาง:
# {'meta': {'status': 200, 'from': {'lon': 100.5018, 'lat': 13.7563}, 'to': {'lon': 100.49904531, 'lat': 13.75976719}, 'config': 'tnullth0'}, 'data': [{'guide': [{'turn': 4, 'name': 'วงเวียนอนุสาวรีย์ประชาธิปไตย', 'distance': 39, 'interval': 11}, {'turn': 2, 'name': 'ถนนราชดำเนินกลาง', 'distance': 292, 'interval': 61}, {'turn': 1, 'name': 'ถนนตะนาว', 'distance': 306, 'interval': 74}, {'turn': 0, 'name': 'ถนนเชื่อมต่อ', 'distance': 8, 'interval': 1}], 'fdistance': 0.9496057, 'tdistance': 8.600729, 'distance': 645, 'interval': 147, 'penalty': 60, 'id': 39807320}]}
#
# กำลังสร้างแผนที่...
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_415283e82acb9b58b8cc04a72b07dadc {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_415283e82acb9b58b8cc04a72b07dadc&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_415283e82acb9b58b8cc04a72b07dadc = L.map(
#                 &quot;map_415283e82acb9b58b8cc04a72b07dadc&quot;,
#                 {
#                     center: [13.7563, 100.5018],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 15,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_12cd05050d4f47f0389810dab47a25ed = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_12cd05050d4f47f0389810dab47a25ed.addTo(map_415283e82acb9b58b8cc04a72b07dadc);
#
#
#             var marker_8dafcd76dabe7d60a4061c73d36bbc0e = L.marker(
#                 [13.7563, 100.5018],
#                 {
# }
#             ).addTo(map_415283e82acb9b58b8cc04a72b07dadc);
#
#
#             var icon_09411e649129fb1e2e4238a1b5381698 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;green&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#             marker_8dafcd76dabe7d60a4061c73d36bbc0e.setIcon(icon_09411e649129fb1e2e4238a1b5381698);
#
#
#         var popup_bd68121cd6415e9ab38cd55d1639e6da = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4b1f3ccf8b63300d1eadf1c41faa0789 = $(`&lt;div id=&quot;html_4b1f3ccf8b63300d1eadf1c41faa0789&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;จุดเริ่มต้น&lt;/div&gt;`)[0];
#                 popup_bd68121cd6415e9ab38cd55d1639e6da.setContent(html_4b1f3ccf8b63300d1eadf1c41faa0789);
#
#
#
#         marker_8dafcd76dabe7d60a4061c73d36bbc0e.bindPopup(popup_bd68121cd6415e9ab38cd55d1639e6da)
#         ;
#
#
#
#
#             var marker_c4b3ca929905a9d04f33f52b32a40ea5 = L.marker(
#                 [13.75976719, 100.49904531],
#                 {
# }
#             ).addTo(map_415283e82acb9b58b8cc04a72b07dadc);
#
#
#             var icon_f1dabf0156c3f068404e261f19f77937 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;red&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#             marker_c4b3ca929905a9d04f33f52b32a40ea5.setIcon(icon_f1dabf0156c3f068404e261f19f77937);
#
#
#         var popup_735812ffd7bc81fe553e1ad4e6f6bb56 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c80d4c7c8483fcf861e8dcad641deb4c = $(`&lt;div id=&quot;html_c80d4c7c8483fcf861e8dcad641deb4c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;จุดปลายทาง&lt;/div&gt;`)[0];
#                 popup_735812ffd7bc81fe553e1ad4e6f6bb56.setContent(html_c80d4c7c8483fcf861e8dcad641deb4c);
#
#
#
#         marker_c4b3ca929905a9d04f33f52b32a40ea5.bindPopup(popup_735812ffd7bc81fe553e1ad4e6f6bb56)
#         ;
#
#
#
#
#             var marker_46a97905aa22efd2ceaf1a178cf11d0d = L.marker(
#                 [13.7563, 100.5018],
#                 {
# }
#             ).addTo(map_415283e82acb9b58b8cc04a72b07dadc);
#
#
#             var icon_2983e67b648648271dbaac75b75ca33a = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;blue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#             marker_46a97905aa22efd2ceaf1a178cf11d0d.setIcon(icon_2983e67b648648271dbaac75b75ca33a);
#
#
#         var popup_c420ab65e62b63cb961c4b4328c155dd = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_780d89d9c8764f9f94765cced42e32cc = $(`&lt;div id=&quot;html_780d89d9c8764f9f94765cced42e32cc&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;จุดที่ 1: วงเวียนอนุสาวรีย์ประชาธิปไตย (39 เมตร)&lt;/div&gt;`)[0];
#                 popup_c420ab65e62b63cb961c4b4328c155dd.setContent(html_780d89d9c8764f9f94765cced42e32cc);
#
#
#
#         marker_46a97905aa22efd2ceaf1a178cf11d0d.bindPopup(popup_c420ab65e62b63cb961c4b4328c155dd)
#         ;
#
#
#
#
#             var marker_b8db43bee4a0f6c13da6e2e1344cdb5a = L.marker(
#                 [13.7563, 100.5018],
#                 {
# }
#             ).addTo(map_415283e82acb9b58b8cc04a72b07dadc);
#
#
#             var icon_2d6f9b389dcd4509cc69145ed6ac8be4 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot

# %%
import folium
from IPython.display import display, HTML
import ipywidgets as widgets
import requests

# ฟังก์ชันสร้างแผนที่พร้อมเส้นทาง
def create_map_with_route(route_data, start_coords, end_coords):
    route_map = folium.Map(location=start_coords, zoom_start=15)

    # เพิ่มจุดเริ่มต้นและปลายทาง
    folium.Marker(start_coords, popup="จุดเริ่มต้น", icon=folium.Icon(color="green")).add_to(route_map)
    folium.Marker(end_coords, popup="จุดปลายทาง", icon=folium.Icon(color="red")).add_to(route_map)

    # ตรวจสอบว่ามีข้อมูล guide หรือไม่
    for route in route_data.get("data", []):
        guides = route.get("guide", [])
        if guides:
            for i, guide in enumerate(guides):
                folium.Marker(
                    start_coords,  # ใช้จุดเริ่มต้นเพื่อแทนที่ตำแหน่งจริง (ถ้าพิกัดไม่มี)
                    popup=f"จุดที่ {i+1}: {guide['name']} ({guide['distance']} เมตร)",
                    icon=folium.Icon(color="blue", icon="info-sign")
                ).add_to(route_map)

    # วาดเส้นระหว่างจุดเริ่มต้นและปลายทาง
    folium.PolyLine([start_coords, end_coords], color="blue", weight=5, opacity=0.7).add_to(route_map)
    return route_map

# ฟังก์ชันแสดงแผนที่
def display_route_map(route_info, user_location, destination_coords):
    print("\nข้อมูลเส้นทาง:")
    print(route_info)

    print("\nกำลังสร้างแผนที่...")
    route_map = create_map_with_route(route_info, user_location, destination_coords)
    route_map_html = route_map._repr_html_()
    display(HTML(route_map_html))

# ฟังก์ชันแสดง Dropdown สำหรับเลือกสถานที่
def display_places_list(places_from_api, user_location):
    if places_from_api and "data" in places_from_api:
        places = places_from_api["data"]

        # สร้างตัวเลือก Dropdown พร้อมพิกัดละติจูดและลองจิจูดจากสถานที่
        options = [(place.get("name", "ไม่ทราบชื่อ"), (place.get("lat"), place.get("lon"))) for place in places]
        dropdown = widgets.Dropdown(
            options=options,
            description='สถานที่:',
            value=options[0][1] if options else None
        )

        # ฟังก์ชันเมื่อเปลี่ยนค่าของ Dropdown
        def on_dropdown_change(change):
            selected_coords = change.new
            if selected_coords:
                dest_lat, dest_lon = selected_coords
                print(f"\nคุณเลือกสถานที่: {dropdown.label}")
                print(f"ละติจูด: {dest_lat}, ลองจิจูด: {dest_lon}")

                # ดึงข้อมูลเส้นทาง
                print("\nกำลังดึงข้อมูลเส้นทาง...")
                # เรียกใช้ฟังก์ชัน get_route โดยใช้พิกัดที่เลือก
                route_info = get_route(user_location[0], user_location[1], dest_lat, dest_lon)
                if route_info:
                    display_route_map(route_info, user_location, (dest_lat, dest_lon))
                else:
                    print("ไม่สามารถดึงข้อมูลเส้นทางได้")

        # ตั้งค่าการทำงานเมื่อมีการเลือกสถานที่
        dropdown.observe(on_dropdown_change, names='value')

        # แสดง Dropdown
        display(dropdown)
    else:
        print("ไม่พบข้อมูลสถานที่ในผลลัพธ์")

# ฟังก์ชันที่ดึงข้อมูลเส้นทาง
def get_route(user_lat, user_lon, dest_lat, dest_lon):
    url = "https://api.longdo.com/RouteService/json/route/guide?"
    params = {
        "flon": user_lon,  # ลองจิจูดของผู้ใช้
        "flat": user_lat,  # ละติจูดของผู้ใช้
        "tlon": dest_lon,  # ลองจิจูดของปลายทาง
        "tlat": dest_lat,  # ละติจูดของปลายทาง
        "mode": "t",  # โมเดลการเดินทาง
        "restrict": 0,
        "locale": "th",
        'key': os.getenv("key_longdo")  # ใช้ API Key จริง
    }

    try:
        response = requests.get(url, params=params)
        
        # ตรวจสอบว่า API ส่งสถานะ 200 (OK) หรือไม่
        if response.status_code == 200:
            data = response.json()
            if "data" in data:
                return data
            else:
                print(f"ข้อมูลเส้นทางไม่พบในผลลัพธ์: {data}")
                return None
        else:
            print(f"เกิดข้อผิดพลาดจาก API: {response.status_code}, Message: {response.text}")
            return None
    except Exception as e:
        print(f"เกิดข้อผิดพลาดในการเชื่อมต่อ API: {e}")
        return None



# ฟังก์ชันประมวลผลคำถามผู้ใช้และค้นหาสถานที่
# (สมมติว่ามีฟังก์ชัน `process_user_query` อยู่แล้ว)
keyword, places_from_api = process_user_query(user_query, user_location, radius)

if keyword:
    print(f"คำค้นหา: {keyword}")
    if places_from_api and "data" in places_from_api:
        print("\nรายชื่อสถานที่:")
        display_places_list(places_from_api, user_location)
    else:
        print("\nไม่พบข้อมูลสถานที่ในผลลัพธ์")
else:
    print("\nไม่พบคำสำคัญจากการประมวลผล")
# Out:
# คำค้นหา: เซเว่น
#
# รายชื่อสถานที่:
# Dropdown(description='สถานที่:', options=(('เซเว่นอิเลฟเว่น ถนนดินสอ จุด 3 (รหัสสาขา: 13597)', (13.75523416, 1…
# คุณเลือกสถานที่: เซเว่นอีเลฟเว่น ตรอกข้าวสาร (รหัสสาขา: 01777)
# ละติจูด: 13.7585479999, ลองจิจูด: 100.498331
#
# กำลังดึงข้อมูลเส้นทาง...
#
# ข้อมูลเส้นทาง:
# {'meta': {'status': 200, 'from': {'lon': 100.5018, 'lat': 13.7563}, 'to': {'lon': 100.498331, 'lat': 13.7585479999}, 'config': 'tnullth0'}, 'data': [{'guide': [{'turn': 4, 'name': 'วงเวียนอนุสาวรีย์ประชาธิปไตย', 'distance': 111, 'interval': 36}, {'turn': 2, 'name': 'ถนนดินสอ', 'distance': 280, 'interval': 98}, {'turn': 0, 'name': 'ถนนพระสุเมรุ', 'distance': 545, 'interval': 63}, {'turn': 0, 'name': 'ถนนจักรพงษ์', 'distance': 397, 'interval': 99}, {'turn': 0, 'name': 'ถนนข้าวสาร', 'distance': 318, 'interval': 177}], 'fdistance': 0.9496057, 'tdistance': 13.058486, 'distance': 1651, 'interval': 473, 'penalty': 75, 'id': 39860571}]}
#
# กำลังสร้างแผนที่...
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d4620754f64ec3c38db7cd21f6e3caef {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d4620754f64ec3c38db7cd21f6e3caef&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_d4620754f64ec3c38db7cd21f6e3caef = L.map(
#                 &quot;map_d4620754f64ec3c38db7cd21f6e3caef&quot;,
#                 {
#                     center: [13.7563, 100.5018],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 15,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_1dbf8e814e5088173c46f01cf36c962e = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_1dbf8e814e5088173c46f01cf36c962e.addTo(map_d4620754f64ec3c38db7cd21f6e3caef);
#
#
#             var marker_5ec49a38a84f071bbabc01e264f36819 = L.marker(
#                 [13.7563, 100.5018],
#                 {
# }
#             ).addTo(map_d4620754f64ec3c38db7cd21f6e3caef);
#
#
#             var icon_60c08e15ef95e333b952452260b5506c = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;green&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#             marker_5ec49a38a84f071bbabc01e264f36819.setIcon(icon_60c08e15ef95e333b952452260b5506c);
#
#
#         var popup_3b2c2a42edc169a1348d77976d5fd219 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_653ed636caaa299cee29186321379d13 = $(`&lt;div id=&quot;html_653ed636caaa299cee29186321379d13&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;จุดเริ่มต้น&lt;/div&gt;`)[0];
#                 popup_3b2c2a42edc169a1348d77976d5fd219.setContent(html_653ed636caaa299cee29186321379d13);
#
#
#
#         marker_5ec49a38a84f071bbabc01e264f36819.bindPopup(popup_3b2c2a42edc169a1348d77976d5fd219)
#         ;
#
#
#
#
#             var marker_656041e3a236580f375a590d82be5127 = L.marker(
#                 [13.7585479999, 100.498331],
#                 {
# }
#             ).addTo(map_d4620754f64ec3c38db7cd21f6e3caef);
#
#
#             var icon_65236e9fb3556f3271ecc05e5a84fa5c = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;red&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#             marker_656041e3a236580f375a590d82be5127.setIcon(icon_65236e9fb3556f3271ecc05e5a84fa5c);
#
#
#         var popup_ba84c47b83218dc95d103e08c17fbfca = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_77402b8fc77417f4d4042a8df02489db = $(`&lt;div id=&quot;html_77402b8fc77417f4d4042a8df02489db&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;จุดปลายทาง&lt;/div&gt;`)[0];
#                 popup_ba84c47b83218dc95d103e08c17fbfca.setContent(html_77402b8fc77417f4d4042a8df02489db);
#
#
#
#         marker_656041e3a236580f375a590d82be5127.bindPopup(popup_ba84c47b83218dc95d103e08c17fbfca)
#         ;
#
#
#
#
#             var marker_094a0e26062aac290e69939bacc6ca56 = L.marker(
#                 [13.7563, 100.5018],
#                 {
# }
#             ).addTo(map_d4620754f64ec3c38db7cd21f6e3caef);
#
#
#             var icon_7ad9fc686ef20c3200c6686821b3c340 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;blue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#             marker_094a0e26062aac290e69939bacc6ca56.setIcon(icon_7ad9fc686ef20c3200c6686821b3c340);
#
#
#         var popup_a40681950343483b3495814b6fe43b9e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6da68960f5cbe53661a719c587d0d629 = $(`&lt;div id=&quot;html_6da68960f5cbe53661a719c587d0d629&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;จุดที่ 1: วงเวียนอนุสาวรีย์ประชาธิปไตย (111 เมตร)&lt;/div&gt;`)[0];
#                 popup_a40681950343483b3495814b6fe43b9e.setContent(html_6da68960f5cbe53661a719c587d0d629);
#
#
#
#         marker_094a0e26062aac290e69939bacc6ca56.bindPopup(popup_a40681950343483b3495814b6fe43b9e)
#         ;
#
#
#
#
#             var marker_a54fba574f761ecb5601c1685dcee199 = L.marker(
#                 [13.7563, 100.5018],
#                 {
# }
#             ).addTo(map_d4620754f64ec3c38db7cd21f6e3caef);
#
#
#             var icon_dbebf48dab4caf81e80c4d5d7c861f1d = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quo
# คุณเลือกสถานที่: เซเว่นอิเลฟเว่น ตรอกมหรรณพาราม (รหัสสาขา: 15076)
# ละติจูด: 13.7536271, ลองจิจูด: 100.50014747
#
# กำลังดึงข้อมูลเส้นทาง...
#
# ข้อมูลเส้นทาง:
# {'meta': {'status': 200, 'from': {'lon': 100.5018, 'lat': 13.7563}, 'to': {'lon': 100.50014747, 'lat': 13.7536271}, 'config': 'tnullth0'}, 'data': [{'guide': [{'turn': 4, 'name': 'วงเวียนอนุสาวรีย์ประชาธิปไตย', 'distance': 39, 'interval': 14}, {'turn': 2, 'name': 'ถนนราชดำเนินกลาง', 'distance': 135, 'interval': 46}, {'turn': 0, 'name': 'ถนนเชื่อมต่อ', 'distance': 55, 'interval': 10}, {'turn': 0, 'name': 'ซอยดำเนินกลางใต้', 'distance': 60, 'interval': 11}, {'turn': 1, 'name': 'ถนนเชื่อมต่อ', 'distance': 144, 'interval': 25}, {'turn': 0, 'name': 'ตรอกศิลป์', 'distance': 71, 'interval': 13}, {'turn': 1, 'name': 'ถนนดินสอ', 'distance': 179, 'interval': 47}, {'turn': 1, 'name': 'ถนนมหรรณพ', 'distance': 107, 'interval': 34}], 'fdistance': 0.9496057, 'tdistance': 9.430536, 'distance': 790, 'interval': 200, 'penalty': 120, 'id': 31509157}]}
#
# กำลังสร้างแผนที่...
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d86d4a1dba8fc0540f2458fedef4a8b7 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d86d4a1dba8fc0540f2458fedef4a8b7&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_d86d4a1dba8fc0540f2458fedef4a8b7 = L.map(
#                 &quot;map_d86d4a1dba8fc0540f2458fedef4a8b7&quot;,
#                 {
#                     center: [13.7563, 100.5018],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 15,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_c7ceeed6868f72635f56c197a39e8bd4 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_c7ceeed6868f72635f56c197a39e8bd4.addTo(map_d86d4a1dba8fc0540f2458fedef4a8b7);
#
#
#             var marker_b87fafb2413a10919dd0717049499d89 = L.marker(
#                 [13.7563, 100.5018],
#                 {
# }
#             ).addTo(map_d86d4a1dba8fc0540f2458fedef4a8b7);
#
#
#             var icon_9bd4ae0ed1747105185bf437c324acb9 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;green&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#             marker_b87fafb2413a10919dd0717049499d89.setIcon(icon_9bd4ae0ed1747105185bf437c324acb9);
#
#
#         var popup_fdcccb0577c50afff6ef1682d2ef0d77 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ba73a89aeac931132e0da167c096df65 = $(`&lt;div id=&quot;html_ba73a89aeac931132e0da167c096df65&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;จุดเริ่มต้น&lt;/div&gt;`)[0];
#                 popup_fdcccb0577c50afff6ef1682d2ef0d77.setContent(html_ba73a89aeac931132e0da167c096df65);
#
#
#
#         marker_b87fafb2413a10919dd0717049499d89.bindPopup(popup_fdcccb0577c50afff6ef1682d2ef0d77)
#         ;
#
#
#
#
#             var marker_aa7fdc9c85a97559796bdba1975f3b45 = L.marker(
#                 [13.7536271, 100.50014747],
#                 {
# }
#             ).addTo(map_d86d4a1dba8fc0540f2458fedef4a8b7);
#
#
#             var icon_d6e87035bd997a3cbb8774b95bc60723 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;red&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#             marker_aa7fdc9c85a97559796bdba1975f3b45.setIcon(icon_d6e87035bd997a3cbb8774b95bc60723);
#
#
#         var popup_ffa29a3ef0fd959150f4f21431e4b0d6 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5a1fa4b582d863f20ae0965eaee49f4d = $(`&lt;div id=&quot;html_5a1fa4b582d863f20ae0965eaee49f4d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;จุดปลายทาง&lt;/div&gt;`)[0];
#                 popup_ffa29a3ef0fd959150f4f21431e4b0d6.setContent(html_5a1fa4b582d863f20ae0965eaee49f4d);
#
#
#
#         marker_aa7fdc9c85a97559796bdba1975f3b45.bindPopup(popup_ffa29a3ef0fd959150f4f21431e4b0d6)
#         ;
#
#
#
#
#             var marker_1c71d4169bf4c27aa5d1fba8150e4257 = L.marker(
#                 [13.7563, 100.5018],
#                 {
# }
#             ).addTo(map_d86d4a1dba8fc0540f2458fedef4a8b7);
#
#
#             var icon_57af8ce259c91387a584ad91159be4de = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;blue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#             marker_1c71d4169bf4c27aa5d1fba8150e4257.setIcon(icon_57af8ce259c91387a584ad91159be4de);
#
#
#         var popup_93fb23cdf8982185aa0d824e50047e6c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e16a6ca6507e95bd18fc59995173d7b6 = $(`&lt;div id=&quot;html_e16a6ca6507e95bd18fc59995173d7b6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;จุดที่ 1: วงเวียนอนุสาวรีย์ประชาธิปไตย (39 เมตร)&lt;/div&gt;`)[0];
#                 popup_93fb23cdf8982185aa0d824e50047e6c.setContent(html_e16a6ca6507e95bd18fc59995173d7b6);
#
#
#
#         marker_1c71d4169bf4c27aa5d1fba8150e4257.bindPopup(popup_93fb23cdf8982185aa0d824e50047e6c)
#         ;
#
#
#
#
#             var marker_6b7cdb0569a24a1886308449d8a1ccd5 = L.marker(
#                 [13.7563, 100.5018],
#                 {
# }
#             ).addTo(map_d86d4a1dba8fc0540f2458fedef4a8b7);
#
#
#             var icon_763a30c244c71bca7ab362b75de49330 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;
